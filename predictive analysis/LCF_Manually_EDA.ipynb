# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams["figure.figsize"]=30,16

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel("/content/drive/MyDrive/LCF_Internal/Renewable_Model/Renewal_Updated.xlsx", sheet_name="data_file")
df
# Out:
#                                                             OpportunityName  \
# 0     0062M00000naLSjQAM      First Call Auto Service-Renewal Deal-10292021
# 1     0062M00000mT0sIQAS      First Call Auto Service-Renewal Deal-08022021
# 2     0062M00000bnQGUQA2     Visual Perfections Salon-Renewal Deal-01142019
# 3     0062M00000cpbP1QAI     Visual Perfections Salon-Renewal Deal-02042019
# 4     0062M00000ibtFXQAY             Med Loan Finance-Renewal Deal-11132019
# ...                  ...                                                ...
# 9563  0062M00000g9CcUQAU                American Made-Renewal Deal-06122019
# 9564  0062M00000bmlCWQAY                     NU Signs-Renewal Deal-01022019
# 9565  0062M00000cD5VPQA0     Beverly Consulting Group-Renewal Deal-02122019
# 9566  0062M00000dHGVXQA4     Beverly Consulting Group-Renewal Deal-02252019
# 9567  0062M00000diZUuQAM  CK 1 Enterprise General Contracting-Renewal De...
#
# ...

# %%
df.shape
# Out:
# (9568, 34)

# %%
df['OpportunityID'].nunique()
# Out:
# 9568

# %%
df['Renewal_PreviousCollectionStatus'].value_counts()
# Out:
# Other        6953
# Default      1909
# Write Off     706
# Name: Renewal_PreviousCollectionStatus, dtype: int64

# %%
df['Renewal_PreviousOpportunityID'].value_counts()[0:20]
# Out:
# 0062M00000mhPNEQA2    10
# 0062M00000mg97hQAA    10
# 0062M00000lvt8HQAQ    10
# 0062M00000n0BfNQAU     9
# 0062M00000iQygZQAS     9
# 0062M00000kxQ5vQAE     9
# 0062M00000dkXrUQAU     9
# 0062M00000lUY9dQAG     8
# 0062M00000nFhacQAC     8
# 0062M00000blGJGQA2     8
# 0064100000b8TtVAAU     8
# 0062M00000nYCldQAG     8
# 0062M00000iba7xQAA     8
# 0062M00000lrWcUQAU     8
# 0062M00000k0gXBQAY     8
# 0062M00000eOnOJQA0     7
# 0062M00000mT4H8QAK     7
# 0062M00000lWNsQQAW     7
# 0062M00000mUgIeQAK     7
# 0062M00000luHYUQA2     7
# Name: Renewal_PreviousOpportunityID, dtype: int64

# %%
df[df['Renewal_PreviousOpportunityID'] == '0062M00000mhPNEQA2']
# Out:
#            OpportunityID                           OpportunityName  \
# 4821  0062M00000nngwIQAQ  Two Meatballs Deli-Renewal Deal-11092021
# 4822  0062M00000mTyLUQA0  Two Meatballs Deli-Renewal Deal-08162021
# 4823  0062M00000n1DmhQAE  Two Meatballs Deli-Renewal Deal-06162021
# 4824  0062M00000n1wpuQAA  Two Meatballs Deli-Renewal Deal-06282021
# 4825  0062M00000o9wvFQAQ  Two Meatballs Deli-Renewal Deal-01252022
# 4826  0062M00000oYVbeQAG  Two Meatballs Deli-Renewal Deal-03282022
# 4827  0062M00000oXbLSQA0  Two Meatballs Deli-Renewal Deal-03182022
# 4828  0062M00000ospNGQAY  Two Meatballs Deli-Renewal Deal-05102022
# 4829  0062M00000nFnolQAC  Two Meatballs Deli-Renewal Deal-07152021
# 4830  0062M00000nqVWfQAM  Two Meatballs Deli-Renewal Deal-12172021
#
#      Renewal_OpportunityID Renewal_PreviousCollectionStatus  \
# 4821    0062M00000nngwIQAQ                            Other
# 4822    0062M00000mTyLUQA0                            Other
# ...

# %%
df['Renewal_PreviousOpportunityID'].value_counts()[0:20]
# Out:
# 0062M00000mhPNEQA2    10
# 0062M00000mg97hQAA    10
# 0062M00000lvt8HQAQ    10
# 0062M00000n0BfNQAU     9
# 0062M00000iQygZQAS     9
# 0062M00000kxQ5vQAE     9
# 0062M00000dkXrUQAU     9
# 0062M00000lUY9dQAG     8
# 0062M00000nFhacQAC     8
# 0062M00000blGJGQA2     8
# 0064100000b8TtVAAU     8
# 0062M00000nYCldQAG     8
# 0062M00000iba7xQAA     8
# 0062M00000lrWcUQAU     8
# 0062M00000k0gXBQAY     8
# 0062M00000eOnOJQA0     7
# 0062M00000mT4H8QAK     7
# 0062M00000lWNsQQAW     7
# 0062M00000mUgIeQAK     7
# 0062M00000luHYUQA2     7
# Name: Renewal_PreviousOpportunityID, dtype: int64

# %%
df['Renewal_PreviousRenewals_Manager'].value_counts()
# Out:
# Amina Mayo          3445
# Robert Mason        2108
# Monique Williams    1492
# Syed Salman         1263
# Kurt Maimaron         30
# Greg Cotter            5
# Carlos Marinez         5
# Jennifer Lindsey       1
# Calvin Handfield       1
# Name: Renewal_PreviousRenewals_Manager, dtype: int64

# %%
df['Renewal_PreviouszzStatus'].value_counts()
# Out:
# Renewed - PIF                 4858
# PIF                           2660
# Write Off                      514
# Default - PIF                  339
# Default - Settled              313
# Current                        275
# Default - Collections          262
# Active                          64
# Write Off - PIF                 52
# Write Off - Settled             40
# Slow Pay                        29
# Write Off - Bankruptcy          28
# Current - Modified              19
# Early Delivery Disc - PIF       11
# Cancelled - Funds Returned       7
# Bankruptcy                       7
# Default Account                  3
# Name: Renewal_PreviouszzStatus, dtype: int64

# %%
df['OpportunityName'].value_counts()[0:20]
# Out:
# Robert Hughes Marine Repair-Renewal Deal-01302017        3
# Hutter Roofing-Renewal Deal-12012020                     3
# Barrette Fine Art-Renewal Deal-01302017                  3
# Braga General Contractor-Renewal Deal-12172020           2
# Hardcore Tennis-Renewal Deal-09182020                    2
# Anabel Cleaning Services-Renewal Deal-01122022           2
# Code Audio-Renewal Deal-07272020                         2
# Monty Tropical Hideout-Renewal Deal-07072021             2
# Wally's Food Truck-Renewal Deal-11242020                 2
# R & J Texas Style BBQ on Wheels-Renewal Deal-07162021    2
# Hardcore Tennis-Renewal Deal-08032020                    2
# C Bar D Oilfield Services-Renewal Deal-01212021          2
# Filthy Filly's BBQ-Renewal Deal-06092021                 2
# Veggies To Go-Renewal Deal-05022022                      2
# General Strategic Resources-Renewal Deal-12082021        2
# Hotel Renovation-Renewal Deal-10062021                   2
# ...

# %%
df['Renewal_PreviousCreatedDate'].sort_values(ascending = False).value_counts()
# Out:
# 2017-01-30 05:21:48    59
# 2017-01-30 05:24:21    22
# 2017-02-06 05:16:09    11
# 2021-04-15 19:42:58    10
# 2021-05-04 00:54:35    10
#                        ..
# 2020-12-08 20:13:32     1
# 2020-12-09 14:13:35     1
# 2020-12-09 15:21:07     1
# 2020-12-09 17:22:50     1
# 2017-01-16 20:12:45     1
# Name: Renewal_PreviousCreatedDate, Length: 6564, dtype: int64

# %%
df['NumberOfBankStatements'].value_counts()
# Out:
# 0    5062
# 3    2086
# 1    1226
# 2    1158
# 4      27
# 5       7
# 6       2
# Name: NumberOfBankStatements, dtype: int64

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 34 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   OpportunityID                         9568 non-null   object
#  1   OpportunityName                       9568 non-null   object
#  2   Renewal_OpportunityID                 9568 non-null   object
#  3   Renewal_PreviousCollectionStatus      9568 non-null   object
#  4   Renewal_PreviousOpportunityID         9568 non-null   object
#  5   Renewal_PreviousCreatedDate           9568 non-null   object
#  6   Renewal_PreviousRenewals_Manager      8350 non-null   object
#  7   Renewal_PreviouszzStatus              9481 non-null   object
#  8   Renewal_PreviousPace                  9249 non-null   float64
#  9   Renewal_PreviousDaysSinceLastPayment  9281 non-null   float64
#  10  Renewal_PreviousPaidPercentageOfRTR   9564 non-null   float64
# ...

# %%
print("No. of features:", len(df.columns))
print("No. of rows:", len(df[:]))
# Out:
# No. of features: 34
# No. of rows: 9568

# %%
numerical_attributes = df.columns[df.dtypes!="object"]
categorical_attributes = df.columns[df.dtypes=="object"]
print("Numerical_attributes :", len(numerical_attributes), "\n")
print(numerical_attributes)
print('\n')
print("Categorical_attributes :", len(categorical_attributes), "\n")
print(categorical_attributes)
# Out:
# Numerical_attributes : 25
#
# Index(['Renewal_PreviousPace', 'Renewal_PreviousDaysSinceLastPayment',
#        'Renewal_PreviousPaidPercentageOfRTR', 'Renewal_PreviousCreditScore',
#        'Renewal_CountPreviousDeals', 'Renewal_PreviousCountBounces',
#        'Renewal_PreviousPosition', 'Renewal_PreviousHBwLCF',
#        'Renewal_PreviousHBwoLCF', 'Renewal_PreviousAvgMonthRevenue',
#        'Renewal_PreviousAvgDailyBalance', 'Renewal_TwoWeekBounces',
#        'NumberOfBankStatements', 'BankStatement_MA_OverdraftDays',
#        'BankStatement_MA_NumReturnItems', 'BankStatement_Sum_NumReturnItems',
#        'LastBankStatement_OverdraftDays', 'Credit_Score__c',
#        'Time_in_Business__c', 'BBC_Position__c', 'HB_with_LCF_Payment__c',
#        'HBwoLCF', 'Contract_HoldBack__c', 'AvgMonthRevenue',
#        'AvgDailyBalance'],
#       dtype='object')
#
#
# Categorical_attributes : 9
#
# Index(['OpportunityID', 'OpportunityName', 'Renewal_OpportunityID',
# ...

# %%
###Analyses on Numerical Attributes

# %% [markdown]
# ## Analyses on Numerical Attributes

# %%
df['Renewal_PreviousPace'].value_counts()
# Out:
# 100.00    7593
# 0.00        56
# 90.00       13
# 66.67       12
# 90.91       12
#           ...
# 35.82        1
# 89.40        1
# 67.08        1
# 75.14        1
# 66.85        1
# Name: Renewal_PreviousPace, Length: 1057, dtype: int64

# %%
df['Renewal_PreviousPace'].plot(kind = 'hist', bins = 10)

# %%
df['Renewal_PreviousPaidPercentageOfRTR'].value_counts()
# Out:
# 1.00    2659
# 0.00     338
# 1.01     290
# 0.53     227
# 0.52     206
#         ...
# 1.91       1
# 2.19       1
# 2.39       1
# 2.41       1
# 1.83       1
# Name: Renewal_PreviousPaidPercentageOfRTR, Length: 199, dtype: int64

# %%
df["Renewal_PreviousPaidPercentageOfRTR"].plot(kind = 'hist', bins = 40)

# %%
from scipy.stats import norm
plt.figure(figsize = (10, 6))
ax = sns.distplot(df["Renewal_PreviousPaidPercentageOfRTR"], fit=norm, kde=False, bins = 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Checking_missing_values_for_each_numerical_attributes

# %%
df[numerical_attributes].isnull().sum().sort_values(ascending=False)
# Out:
# HBwoLCF                                 8115
# LastBankStatement_OverdraftDays         5808
# Credit_Score__c                         5429
# Renewal_PreviousHBwoLCF                 5063
# BankStatement_MA_NumReturnItems         5062
# BankStatement_Sum_NumReturnItems        5062
# BankStatement_MA_OverdraftDays          5062
# AvgMonthRevenue                         3953
# AvgDailyBalance                         3328
# Renewal_PreviousAvgMonthRevenue         3020
# BBC_Position__c                         2401
# Renewal_PreviousAvgDailyBalance         1837
# Renewal_PreviousCreditScore             1194
# Renewal_PreviousPosition                 751
# Renewal_PreviousPace                     319
# Renewal_PreviousDaysSinceLastPayment     287
# Time_in_Business__c                      169
# Renewal_PreviousPaidPercentageOfRTR        4
# Renewal_TwoWeekBounces                     0
# Renewal_PreviousHBwLCF                     0
# Renewal_PreviousCountBounces               0
# ...

# %%
df[numerical_attributes].isnull().sum().sort_values(ascending=False)/len(df)  # In Percentages %
# Out:
# HBwoLCF                                 0.848140
# LastBankStatement_OverdraftDays         0.607023
# Credit_Score__c                         0.567412
# Renewal_PreviousHBwoLCF                 0.529160
# BankStatement_MA_NumReturnItems         0.529055
# BankStatement_Sum_NumReturnItems        0.529055
# BankStatement_MA_OverdraftDays          0.529055
# AvgMonthRevenue                         0.413148
# AvgDailyBalance                         0.347826
# Renewal_PreviousAvgMonthRevenue         0.315635
# BBC_Position__c                         0.250941
# Renewal_PreviousAvgDailyBalance         0.191994
# Renewal_PreviousCreditScore             0.124791
# Renewal_PreviousPosition                0.078491
# Renewal_PreviousPace                    0.033340
# Renewal_PreviousDaysSinceLastPayment    0.029996
# Time_in_Business__c                     0.017663
# Renewal_PreviousPaidPercentageOfRTR     0.000418
# Renewal_TwoWeekBounces                  0.000000
# ...

# %% [markdown]
# #### checking_missing_values_for_each_categorical_attributes

# %%
df[categorical_attributes].isnull().sum().sort_values(ascending=False)
# Out:
# Renewal_PreviousRenewals_Manager    1218
# Is_this_Business_home_based__c       975
# Renewal_PreviouszzStatus              87
# OpportunityID                          0
# OpportunityName                        0
# Renewal_OpportunityID                  0
# Renewal_PreviousCollectionStatus       0
# Renewal_PreviousOpportunityID          0
# Renewal_PreviousCreatedDate            0
# dtype: int64

# %%
df[categorical_attributes].isnull().sum().sort_values(ascending=False)/len(df)    # In Percentages %
# Out:
# Renewal_PreviousRenewals_Manager    0.127299
# Is_this_Business_home_based__c      0.101902
# Renewal_PreviouszzStatus            0.009093
# OpportunityID                       0.000000
# OpportunityName                     0.000000
# Renewal_OpportunityID               0.000000
# Renewal_PreviousCollectionStatus    0.000000
# Renewal_PreviousOpportunityID       0.000000
# Renewal_PreviousCreatedDate         0.000000
# dtype: float64

# %%
df.dtypes
# Out:
# OpportunityID                            object
# OpportunityName                          object
# Renewal_OpportunityID                    object
# Renewal_PreviousCollectionStatus         object
# Renewal_PreviousOpportunityID            object
# Renewal_PreviousCreatedDate              object
# Renewal_PreviousRenewals_Manager         object
# Renewal_PreviouszzStatus                 object
# Renewal_PreviousPace                    float64
# Renewal_PreviousDaysSinceLastPayment    float64
# Renewal_PreviousPaidPercentageOfRTR     float64
# Renewal_PreviousCreditScore             float64
# Renewal_CountPreviousDeals                int64
# Renewal_PreviousCountBounces              int64
# Renewal_PreviousPosition                float64
# Renewal_PreviousHBwLCF                  float64
# Renewal_PreviousHBwoLCF                 float64
# Renewal_PreviousAvgMonthRevenue         float64
# Renewal_PreviousAvgDailyBalance         float64
# Renewal_TwoWeekBounces                    int64
# ...

# %% [markdown]
# ## Getting the highly correlated features

# %%
cor=df.corr()
cor
# Out:
#                                       Renewal_PreviousPace  \
# Renewal_PreviousPace                              1.000000
# Renewal_PreviousDaysSinceLastPayment             -0.504501
# Renewal_PreviousPaidPercentageOfRTR               0.205214
# Renewal_PreviousCreditScore                       0.017927
# Renewal_CountPreviousDeals                       -0.016186
# Renewal_PreviousCountBounces                     -0.206172
# Renewal_PreviousPosition                         -0.034445
# Renewal_PreviousHBwLCF                            0.013248
# Renewal_PreviousHBwoLCF                          -0.001708
# Renewal_PreviousAvgMonthRevenue                  -0.043323
# Renewal_PreviousAvgDailyBalance                  -0.020815
# Renewal_TwoWeekBounces                           -0.083032
# NumberOfBankStatements                            0.100114
# BankStatement_MA_OverdraftDays                   -0.179681
# BankStatement_MA_NumReturnItems                  -0.177295
# ...

# %%
sns.heatmap(cor, xticklabels=cor.columns, yticklabels=cor.columns, annot=True)
rcParams["figure.figsize"]=30,14

# %% [markdown]
# ## This is function which returns the highly correlated features :-
#
# * These correlated features having similar information of other features in the dataset. Because two features represents highly similar information
# * Example - BankStatement_MA_NumReturnItems && BankStatement_Sum_NumReturnItems (0.89)
# * So we can drop these features while building the model.

# %%
def corelation(df,thresold):
    cor_cor=set()
    cor_matrix=df.corr()
    for i in range(len(cor_matrix.columns)):
        for j in range(i):
            if (cor_matrix.iloc[i,j])>thresold:
                colname=cor_matrix.columns[i]
                cor_cor.add(colname)
    return cor_cor

# %%
# Setting a threshold - 70% - this will provide features which are highly correlated with other features in the above matrix
corelation(df,0.7)
# Out:
# {'AvgDailyBalance',
#  'BBC_Position__c',
#  'BankStatement_Sum_NumReturnItems',
#  'Credit_Score__c'}

# %%
cor_features=corelation(df,0.7)
print(len(set(cor_features)),'\n')
cor_features
# Out:
# 4
# {'AvgDailyBalance',
#  'BBC_Position__c',
#  'BankStatement_Sum_NumReturnItems',
#  'Credit_Score__c'}

# %% [markdown]
# ## Checking_duplicacy_of_data

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9563    False
# 9564    False
# 9565    False
# 9566    False
# 9567    False
# Length: 9568, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Getting the numerical features for plotting the graphs

# %%
df_num = df.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#    Renewal_PreviousPace  Renewal_PreviousDaysSinceLastPayment  \
# 0                 100.0                                   0.0
# 1                 100.0                                   0.0
# 2                 100.0                                   0.0
# 3                 100.0                                   0.0
# 4                 100.0                                   0.0
#
#    Renewal_PreviousPaidPercentageOfRTR  Renewal_PreviousCreditScore  \
# 0                                 0.73                          0.0
# 1                                 0.64                          0.0
# 2                                 1.00                        629.0
# 3                                 1.00                        629.0
# 4                                 0.81                        601.0
#
#    Renewal_CountPreviousDeals  Renewal_PreviousCountBounces  \
# 0                           2                            14
# ...

# %%
df_num.describe()
# Out:
#        Renewal_PreviousPace  Renewal_PreviousDaysSinceLastPayment  \
# count           9249.000000                           9281.000000
# mean              95.424737                             16.546816
# std               14.843865                            164.290098
# min                0.000000                            -23.000000
# 25%              100.000000                              0.000000
# 50%              100.000000                              0.000000
# 75%              100.000000                              0.000000
# max              100.000000                           2704.000000
#
#        Renewal_PreviousPaidPercentageOfRTR  Renewal_PreviousCreditScore  \
# count                          9564.000000                  8374.000000
# mean                              0.837153                   546.106878
# std                               0.315417                   162.279575
# min                               0.000000                     0.000000
# ...

# %%
df_num.hist(figsize=(26, 20), bins=50, xlabelsize=8, ylabelsize=8); # avoid having the matplotlib verbose informations

# %% [markdown]
# ## Plotting the features values

# %%
# Plotted graphs
plt.plot(df_num['Renewal_PreviousCreditScore'][0:500], color = 'red', label = 'Renewal_previous_credit_score')
plt.legend(loc='best')
plt.grid()
plt.title('Rolling Mean and Standard Deviation')
plt.show()
rcParams["figure.figsize"]=12,8

# %%
plt.plot(df_num['Credit_Score__c'][0:500], color = 'black', label = 'Credit_Score__c')
plt.legend(loc='best')
plt.grid()
plt.title('Rolling Mean and Standard Deviation')
plt.show()
rcParams["figure.figsize"]=16,8

# %%
df_num[['Renewal_PreviousCreditScore', 'Credit_Score__c']][0:500].plot(subplots=True)
rcParams['figure.figsize'] = 15,8

# %%
df_num[['Renewal_CountPreviousDeals', 'Renewal_PreviousPosition', 'LastBankStatement_OverdraftDays']][:].plot(subplots=True)
rcParams['figure.figsize'] = 16,8

# %%
df_num[['Renewal_CountPreviousDeals', 'Renewal_PreviousPosition', 'LastBankStatement_OverdraftDays']][0:500].plot(subplots=True)
rcParams['figure.figsize'] = 16,8
