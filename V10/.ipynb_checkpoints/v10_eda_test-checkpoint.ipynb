# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_excel("/content/drive/MyDrive/LCF_Internal/Renewable_Model/EDA Approach-1/XGBoost Implementation/v10/v10_updated_V1.6.xlsx", sheet_name = 'v10_test')
data.head()
# Out:
#         OpportunityID         CreatedDate FundedDate  \
# 0  0062M00000nqf6oQAA 2021-12-20 21:03:51 2022-01-06
# 1  0062M00000nqfF3QAI 2021-12-20 21:45:40 2022-01-05
# 2  0062M00000nqjtvQAA 2021-12-21 19:11:21 2022-01-18
# 3  0062M00000nqs8FQAQ 2021-12-23 15:58:53 2022-01-13
# 4  0062M00000nr94cQAA 2021-12-28 21:45:27 2022-01-04
#
#                                      OpportunityName     Priordeal_OppID  \
# 0       G Smith Handyman Group-Renewal Deal-12202021  0062M00000nYhn5QAC
# 1        Green Collar Cleaners-Renewal Deal-12202021  0062M00000nZHYfQAO
# 2   JC Building And Remodeling-Renewal Deal-12212021  0062M00000na4fuQAA
# 3  Sykes Funeral Trade Service-Renewal Deal-12232021  0062M00000nYYdkQAG
# 4              Monrovia Lounge-Renewal Deal-12282021  0062M00000nWwtLQAS
#
#   Renewal_PreviousCollectionStatus  Renewal_PreviousPace  \
# 0                            Other                100.00
# 1                            Other                100.00
# 2                            Other                100.00
# 3                            Other                100.00
# 4                            Other                 98.33
#
#    Renewal_PreviousPaidPercentageOfRTR  Renewal_PreviousCreditScore  \
# 0                                 0.90                        642.0
# 1                                 0.78                        507.0
# 2                                 0.49                        611.0
# 3                                 0.60                        762.0
# 4                                 0.56                        614.0
#
#    Renewal_CountPreviousDeals  ...      Industry  \
# 0                         1.0  ...      Services
# 1                         1.0  ...      Services
# 2                         3.0  ...  Construction
# 3                         1.0  ...      Services
# 4                         1.0  ...      Services
#
#                                    Industry_Group__c  Avg_ReturnItemdays  \
# 0  76 - Miscellaneous Repair & Installation Services                 0.0
# 1                             72 - Personal Services                 1.0
# 2  15 - Building Construction General Contractors...                 0.0
# 3                             72 - Personal Services                 0.0
# 4                            90 - Restaurants & Bars                 0.0
#
#    LatestMonth_ReturnItemDays  PctChangeInReveune  \
# 0                         NaN           -0.836880
# 1                         2.0            0.175900
# 2                         0.0            0.190589
# 3                         NaN           -0.161054
# 4                         0.0           -0.119529
#
#    PctAvgDailybalance2AvgMonthlyDeposits  TwoMonthAvg_AdjustedMonthlyDeposits  \
# 0                               0.343163                         10817.030000
# 1                               0.049731                         15537.289000
# 2                               0.244433                         41386.190000
# 3                               1.624795                          5817.666666
# 4                               0.207955                         17809.837142
#
#    AdjustedMonthlyDeposits  drop_percent  Drop_category
# 0                  7834.00    -27.577163       Negative
# 1                 18395.59     18.396388       Positive
# 2                 34545.34    -16.529306       Negative
# 3                  7310.00     25.651693       Positive
# 4                 10224.94    -42.588261       Negative
#
# [5 rows x 55 columns]

# %%
data.shape
# Out:
# (488, 55)

# %%
data["NumberOfBankStatements"].value_counts()
# Out:
# 3.0    247
# 4.0    203
# 2.0     37
# 1.0      1
# Name: NumberOfBankStatements, dtype: int64

# %% [markdown]
# # Check Anomalies
#
# 1. Perform EDA
# 2. check wos - remove missing but give in excel sheet:
# 3. Specifically take care of no of bank statements and all other attributes related to it:
# 4. Check again the pace rates - {check for extreme weird values} - min_val_check
# 5. Check for anomalies - time in business -ve_values
# 6. is this business home based - flag based  -
# 7. take care of features to be dropped - take previous references
# 8. fill the missing values - so as to keep the progress alive:
# 9. EDA is completed - save the file

# %%
numerical_attributes = data.columns[data.dtypes!="object"]
categorical_attributes = data.columns[data.dtypes=="object"]
print("Numerical_attributes :", len(numerical_attributes), "\n")
print(numerical_attributes)
print('\n')
print("Categorical_attributes :", len(categorical_attributes), "\n")
print(categorical_attributes)
# Out:
# Numerical_attributes : 47
#
# Index(['CreatedDate', 'FundedDate', 'Renewal_PreviousPace',
#        'Renewal_PreviousPaidPercentageOfRTR', 'Renewal_PreviousCreditScore',
#        'Renewal_CountPreviousDeals', 'Renewal_PreviousCountBounces',
#        'Renewal_PreviousPosition', 'Renewal_PreviousHBwLCF',
#        'Renewal_PreviousHBwoLCF', 'Renewal_PreviousAvgMonthRevenue',
#        'Renewal_PreviousAvgDailyBalance', 'Renewal_TwoWeekBounces',
#        'NumberOfBankStatements', 'Last3Months_MA_OverdraftDays',
#        'Last3Months_MA_NumReturnItems', 'Last3Months_Sum_NumReturnItems',
#        'LastBankStatement_OverdraftDays',
#        'Last3Months_MA_AdjustedMonthlyDeposits',
#        'Last3Months_MA_AvgDailyBalance', 'Credit_Score__c',
#        'Time_in_Business__c', 'BBC_Position__c', 'HB_with_LCF_Payment__c',
#        'HBwoLCF', 'Contract_HoldBack__c',
#        'Last3Statments_MA_AdjustedMonthlyDeposits',
#        'Last3Statments_MA_AvgDailyBalance', 'Last3Statments_MA_ReturnItemDays',
#        'Last3Statments_MA_OverdraftDays', 'Last3Statments_MA_NumReturnItems',
#        'Last3Statments_Sum_NumReturnItems', 'FundedAmount', 'Paybackamount',
#        'NewDeal_YN', 'ActiveDeal_YN', 'WriteOff_YN',
#        'FundedWriteOffAmount_Gross', 'WOGross_AdvanceBalance', 'NetWO',
#        'Avg_ReturnItemdays', 'LatestMonth_ReturnItemDays',
#        'PctChangeInReveune', 'PctAvgDailybalance2AvgMonthlyDeposits',
#        'TwoMonthAvg_AdjustedMonthlyDeposits', 'AdjustedMonthlyDeposits',
#        'drop_percent'],
#       dtype='object')
#
#
# Categorical_attributes : 8
#
# Index(['OpportunityID', 'OpportunityName', 'Priordeal_OppID',
#        'Renewal_PreviousCollectionStatus', 'Is_this_Business_home_based__c',
#        'Industry', 'Industry_Group__c', 'Drop_category'],
#       dtype='object')

# %%
data.isna().sum().sort_values(ascending = False)/len(data)*100
# Out:
# HBwoLCF                                      97.336066
# NetWO                                        76.434426
# Renewal_PreviousHBwoLCF                      65.983607
# LatestMonth_ReturnItemDays                   50.204918
# Renewal_PreviousCreditScore                   2.254098
# PctChangeInReveune                            2.254098
# Credit_Score__c                               1.844262
# Renewal_PreviousAvgDailyBalance               1.639344
# Renewal_PreviousAvgMonthRevenue               1.639344
# Renewal_PreviousPace                          0.409836
# Renewal_PreviousPaidPercentageOfRTR           0.409836
# LastBankStatement_OverdraftDays               0.409836
# NewDeal_YN                                    0.000000
# OpportunityID                                 0.000000
# Paybackamount                                 0.000000
# FundedAmount                                  0.000000
# Last3Statments_Sum_NumReturnItems             0.000000
# Last3Statments_MA_NumReturnItems              0.000000
# Last3Statments_MA_OverdraftDays               0.000000
# ActiveDeal_YN                                 0.000000
# Industry                                      0.000000
# WriteOff_YN                                   0.000000
# FundedWriteOffAmount_Gross                    0.000000
# WOGross_AdvanceBalance                        0.000000
# Last3Statments_MA_AvgDailyBalance             0.000000
# Industry_Group__c                             0.000000
# Avg_ReturnItemdays                            0.000000
# PctAvgDailybalance2AvgMonthlyDeposits         0.000000
# TwoMonthAvg_AdjustedMonthlyDeposits           0.000000
# AdjustedMonthlyDeposits                       0.000000
# drop_percent                                  0.000000
# Last3Statments_MA_ReturnItemDays              0.000000
# BBC_Position__c                               0.000000
# Last3Statments_MA_AdjustedMonthlyDeposits     0.000000
# Contract_HoldBack__c                          0.000000
# FundedDate                                    0.000000
# OpportunityName                               0.000000
# Priordeal_OppID                               0.000000
# Renewal_PreviousCollectionStatus              0.000000
# Renewal_CountPreviousDeals                    0.000000
# Renewal_PreviousCountBounces                  0.000000
# Renewal_PreviousPosition                      0.000000
# Renewal_PreviousHBwLCF                        0.000000
# Renewal_TwoWeekBounces                        0.000000
# NumberOfBankStatements                        0.000000
# Last3Months_MA_OverdraftDays                  0.000000
# Last3Months_MA_NumReturnItems                 0.000000
# Last3Months_Sum_NumReturnItems                0.000000
# Last3Months_MA_AdjustedMonthlyDeposits        0.000000
# Last3Months_MA_AvgDailyBalance                0.000000
# Time_in_Business__c                           0.000000
# Is_this_Business_home_based__c                0.000000
# CreatedDate                                   0.000000
# HB_with_LCF_Payment__c                        0.000000
# Drop_category                                 0.000000
# dtype: float64

# %%
data.corr()["WriteOff_YN"].sort_values()
# Out:
# NumberOfBankStatements                      -0.307697
# ActiveDeal_YN                               -0.245872
# Renewal_CountPreviousDeals                  -0.108062
# Last3Months_MA_AvgDailyBalance              -0.104783
# Last3Statments_MA_AvgDailyBalance           -0.097053
# Contract_HoldBack__c                        -0.086297
# Renewal_PreviousAvgDailyBalance             -0.080234
# Renewal_PreviousPaidPercentageOfRTR         -0.078289
# Paybackamount                               -0.068494
# FundedAmount                                -0.068365
# PctAvgDailybalance2AvgMonthlyDeposits       -0.065034
# Time_in_Business__c                         -0.064839
# Last3Months_MA_OverdraftDays                -0.052391
# TwoMonthAvg_AdjustedMonthlyDeposits         -0.050436
# Avg_ReturnItemdays                          -0.048897
# Last3Statments_MA_ReturnItemDays            -0.047456
# Renewal_PreviousHBwoLCF                     -0.045602
# Renewal_PreviousCreditScore                 -0.044504
# Last3Statments_MA_OverdraftDays             -0.043428
# Last3Months_Sum_NumReturnItems              -0.042112
# LatestMonth_ReturnItemDays                  -0.042105
# Credit_Score__c                             -0.039941
# Renewal_PreviousPace                        -0.038024
# Renewal_PreviousAvgMonthRevenue             -0.035984
# HB_with_LCF_Payment__c                      -0.027820
# Last3Months_MA_NumReturnItems               -0.020930
# Last3Statments_MA_NumReturnItems            -0.016423
# Last3Statments_Sum_NumReturnItems           -0.015188
# Renewal_PreviousHBwLCF                      -0.008105
# Last3Months_MA_AdjustedMonthlyDeposits      -0.003462
# Renewal_PreviousCountBounces                -0.000531
# LastBankStatement_OverdraftDays              0.008629
# Last3Statments_MA_AdjustedMonthlyDeposits    0.010578
# PctChangeInReveune                           0.019164
# NewDeal_YN                                   0.027435
# AdjustedMonthlyDeposits                      0.030301
# drop_percent                                 0.057128
# Renewal_PreviousPosition                     0.061281
# BBC_Position__c                              0.075055
# Renewal_TwoWeekBounces                       0.128622
# HBwoLCF                                      0.252693
# FundedWriteOffAmount_Gross                   0.330304
# WOGross_AdvanceBalance                       0.392397
# WriteOff_YN                                  1.000000
# NetWO                                             NaN
# Name: WriteOff_YN, dtype: float64

# %%
data[["Last3Statments_MA_ReturnItemDays",
     "Last3Statments_MA_OverdraftDays",
     "Last3Statments_Sum_NumReturnItems",
     "Last3Statments_MA_NumReturnItems",
     "Last3Statments_MA_AdjustedMonthlyDeposits", 
     "Last3Statments_MA_AvgDailyBalance", 
     "Last3Statments_MA_ReturnItemDays", "WriteOff_YN"]].corr()['WriteOff_YN'].sort_values()
# Out:
# Last3Statments_MA_AvgDailyBalance           -0.097053
# Last3Statments_MA_ReturnItemDays            -0.047456
# Last3Statments_MA_ReturnItemDays            -0.047456
# Last3Statments_MA_OverdraftDays             -0.043428
# Last3Statments_MA_NumReturnItems            -0.016423
# Last3Statments_Sum_NumReturnItems           -0.015188
# Last3Statments_MA_AdjustedMonthlyDeposits    0.010578
# WriteOff_YN                                  1.000000
# Name: WriteOff_YN, dtype: float64

# %%
data[["Last3Months_Sum_NumReturnItems",
     "Last3Months_MA_NumReturnItems",
     "Last3Months_MA_AvgDailyBalance",
     "Last3Months_MA_AdjustedMonthlyDeposits",
     "Last3Months_MA_OverdraftDays",
    "WriteOff_YN"]].corr()["WriteOff_YN"].sort_values()
# Out:
# Last3Months_MA_AvgDailyBalance           -0.104783
# Last3Months_MA_OverdraftDays             -0.052391
# Last3Months_Sum_NumReturnItems           -0.042112
# Last3Months_MA_NumReturnItems            -0.020930
# Last3Months_MA_AdjustedMonthlyDeposits   -0.003462
# WriteOff_YN                               1.000000
# Name: WriteOff_YN, dtype: float64

# %% [markdown]
# # Dropped the unwanted features

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 55 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   OpportunityID                              488 non-null    object
#  1   CreatedDate                                488 non-null    datetime64[ns]
#  2   FundedDate                                 488 non-null    datetime64[ns]
#  3   OpportunityName                            488 non-null    object
#  4   Priordeal_OppID                            488 non-null    object
#  5   Renewal_PreviousCollectionStatus           488 non-null    object
#  6   Renewal_PreviousPace                       486 non-null    float64
#  7   Renewal_PreviousPaidPercentageOfRTR        486 non-null    float64
#  8   Renewal_PreviousCreditScore                477 non-null    float64
#  9   Renewal_CountPreviousDeals                 488 non-null    float64
#  10  Renewal_PreviousCountBounces               488 non-null    float64
#  11  Renewal_PreviousPosition                   488 non-null    float64
#  12  Renewal_PreviousHBwLCF                     488 non-null    float64
#  13  Renewal_PreviousHBwoLCF                    166 non-null    float64
#  14  Renewal_PreviousAvgMonthRevenue            480 non-null    float64
#  15  Renewal_PreviousAvgDailyBalance            480 non-null    float64
#  16  Renewal_TwoWeekBounces                     488 non-null    float64
#  17  NumberOfBankStatements                     488 non-null    float64
#  18  Last3Months_MA_OverdraftDays               488 non-null    float64
#  19  Last3Months_MA_NumReturnItems              488 non-null    float64
#  20  Last3Months_Sum_NumReturnItems             488 non-null    float64
#  21  LastBankStatement_OverdraftDays            486 non-null    float64
#  22  Last3Months_MA_AdjustedMonthlyDeposits     488 non-null    float64
#  23  Last3Months_MA_AvgDailyBalance             488 non-null    float64
#  24  Credit_Score__c                            479 non-null    float64
#  25  Time_in_Business__c                        488 non-null    float64
#  26  Is_this_Business_home_based__c             488 non-null    object
#  27  BBC_Position__c                            488 non-null    float64
#  28  HB_with_LCF_Payment__c                     488 non-null    float64
#  29  HBwoLCF                                    13 non-null     float64
#  30  Contract_HoldBack__c                       488 non-null    float64
#  31  Last3Statments_MA_AdjustedMonthlyDeposits  488 non-null    float64
#  32  Last3Statments_MA_AvgDailyBalance          488 non-null    float64
#  33  Last3Statments_MA_ReturnItemDays           488 non-null    float64
#  34  Last3Statments_MA_OverdraftDays            488 non-null    float64
#  35  Last3Statments_MA_NumReturnItems           488 non-null    float64
#  36  Last3Statments_Sum_NumReturnItems          488 non-null    float64
#  37  FundedAmount                               488 non-null    float64
#  38  Paybackamount                              488 non-null    float64
#  39  NewDeal_YN                                 488 non-null    float64
#  40  ActiveDeal_YN                              488 non-null    float64
#  41  WriteOff_YN                                488 non-null    float64
#  42  FundedWriteOffAmount_Gross                 488 non-null    float64
#  43  WOGross_AdvanceBalance                     488 non-null    float64
#  44  NetWO                                      115 non-null    float64
#  45  Industry                                   488 non-null    object
#  46  Industry_Group__c                          488 non-null    object
#  47  Avg_ReturnItemdays                         488 non-null    float64
#  48  LatestMonth_ReturnItemDays                 243 non-null    float64
#  49  PctChangeInReveune                         477 non-null    float64
#  50  PctAvgDailybalance2AvgMonthlyDeposits      488 non-null    float64
#  51  TwoMonthAvg_AdjustedMonthlyDeposits        488 non-null    float64
#  52  AdjustedMonthlyDeposits                    488 non-null    float64
#  53  drop_percent                               488 non-null    float64
#  54  Drop_category                              488 non-null    object
# dtypes: datetime64[ns](2), float64(45), object(8)
# memory usage: 209.8+ KB

# %%
# Dropped unwanted features
data =  data.drop(['OpportunityName',
                   'Priordeal_OppID',
                   'CreatedDate',
                   'FundedDate', 
                   'Industry_Group__c',
                   'Renewal_PreviousCollectionStatus',
                   'ActiveDeal_YN',
                   'NewDeal_YN',
                   'Renewal_PreviousCreditScore',
                   'LastBankStatement_OverdraftDays',
                   'HBwoLCF',
                   'Contract_HoldBack__c',
                   'Renewal_PreviousHBwoLCF',
                   'NetWO',
                   
                   "Last3Months_Sum_NumReturnItems",
                   "Last3Months_MA_NumReturnItems",
                   "Last3Months_MA_AvgDailyBalance",
                   "Last3Months_MA_AdjustedMonthlyDeposits",
                   "Last3Months_MA_OverdraftDays"], axis=1)

# %%
data.shape
# Out:
# (488, 36)

# %%
data.isna().sum().sort_values(ascending = False)/len(data)*100
# Out:
# LatestMonth_ReturnItemDays                   50.204918
# PctChangeInReveune                            2.254098
# Credit_Score__c                               1.844262
# Renewal_PreviousAvgMonthRevenue               1.639344
# Renewal_PreviousAvgDailyBalance               1.639344
# Renewal_PreviousPaidPercentageOfRTR           0.409836
# Renewal_PreviousPace                          0.409836
# Industry                                      0.000000
# Paybackamount                                 0.000000
# WriteOff_YN                                   0.000000
# FundedWriteOffAmount_Gross                    0.000000
# WOGross_AdvanceBalance                        0.000000
# OpportunityID                                 0.000000
# Avg_ReturnItemdays                            0.000000
# Last3Statments_Sum_NumReturnItems             0.000000
# PctAvgDailybalance2AvgMonthlyDeposits         0.000000
# TwoMonthAvg_AdjustedMonthlyDeposits           0.000000
# AdjustedMonthlyDeposits                       0.000000
# drop_percent                                  0.000000
# FundedAmount                                  0.000000
# Last3Statments_MA_ReturnItemDays              0.000000
# Last3Statments_MA_NumReturnItems              0.000000
# Last3Statments_MA_OverdraftDays               0.000000
# Last3Statments_MA_AvgDailyBalance             0.000000
# Last3Statments_MA_AdjustedMonthlyDeposits     0.000000
# HB_with_LCF_Payment__c                        0.000000
# BBC_Position__c                               0.000000
# Is_this_Business_home_based__c                0.000000
# Time_in_Business__c                           0.000000
# NumberOfBankStatements                        0.000000
# Renewal_TwoWeekBounces                        0.000000
# Renewal_PreviousHBwLCF                        0.000000
# Renewal_PreviousPosition                      0.000000
# Renewal_PreviousCountBounces                  0.000000
# Renewal_CountPreviousDeals                    0.000000
# Drop_category                                 0.000000
# dtype: float64

# %%
numerical_attributes = data.columns[data.dtypes!="object"]
categorical_attributes = data.columns[data.dtypes=="object"]
print("Numerical_attributes :", len(numerical_attributes), "\n")
print(numerical_attributes)
print('\n')
print("Categorical_attributes :", len(categorical_attributes), "\n")
print(categorical_attributes)
# Out:
# Numerical_attributes : 32
#
# Index(['Renewal_PreviousPace', 'Renewal_PreviousPaidPercentageOfRTR',
#        'Renewal_CountPreviousDeals', 'Renewal_PreviousCountBounces',
#        'Renewal_PreviousPosition', 'Renewal_PreviousHBwLCF',
#        'Renewal_PreviousAvgMonthRevenue', 'Renewal_PreviousAvgDailyBalance',
#        'Renewal_TwoWeekBounces', 'NumberOfBankStatements', 'Credit_Score__c',
#        'Time_in_Business__c', 'BBC_Position__c', 'HB_with_LCF_Payment__c',
#        'Last3Statments_MA_AdjustedMonthlyDeposits',
#        'Last3Statments_MA_AvgDailyBalance', 'Last3Statments_MA_ReturnItemDays',
#        'Last3Statments_MA_OverdraftDays', 'Last3Statments_MA_NumReturnItems',
#        'Last3Statments_Sum_NumReturnItems', 'FundedAmount', 'Paybackamount',
#        'WriteOff_YN', 'FundedWriteOffAmount_Gross', 'WOGross_AdvanceBalance',
#        'Avg_ReturnItemdays', 'LatestMonth_ReturnItemDays',
#        'PctChangeInReveune', 'PctAvgDailybalance2AvgMonthlyDeposits',
#        'TwoMonthAvg_AdjustedMonthlyDeposits', 'AdjustedMonthlyDeposits',
#        'drop_percent'],
#       dtype='object')
#
#
# Categorical_attributes : 4
#
# Index(['OpportunityID', 'Is_this_Business_home_based__c', 'Industry',
#        'Drop_category'],
#       dtype='object')

# %%
# with pd.ExcelWriter('/content/drive/MyDrive/missing_values_v7_train_data.xlsx') as writer:
#   data[data['PctChangeInReveune'].isna()].to_excel(writer, sheet_name = 'PctChangeInReveune')
#   data[data['LatestMonth_ReturnItemDays'].isna()].to_excel(writer, sheet_name = 'LatestMonth_ReturnItemDays')
#   data[data['Renewal_PreviousPaidPercentageOfRTR'].isna()].to_excel(writer, sheet_name = 'Renewal_PreviousPaidPercentageOfRTR')
#   data[data['Renewal_PreviousAvgMonthRevenue'].isna()].to_excel(writer, sheet_name = 'Renewal_PreviousAvgMonthRevenue')
#   data[data['PctAvgDailybalance2AvgMonthlyDeposits'].isna()].to_excel(writer, sheet_name = 'PctAvgDailybalance2AvgMonthlyDeposits')
#   data[data['AvgMonthlydeposits'].isna()].to_excel(writer, sheet_name = 'AvgMonthlydeposits')
#   data[data['Renewal_PreviousAvgDailyBalance'].isna()].to_excel(writer, sheet_name = 'Renewal_PreviousAvgDailyBalance')
#   data[data['AvgDailybalance'].isna()].to_excel(writer, sheet_name = 'AvgDailybalance')
#   data[data['Avg_ReturnItemdays'].isna()].to_excel(writer, sheet_name = 'Avg_ReturnItemdays')
#   data[data['BankStatement_MA_OverdraftDays'].isna()].to_excel(writer, sheet_name = 'BankStatement_MA_OverdraftDays')
#   data[data['BankStatement_MA_NumReturnItems'].isna()].to_excel(writer, sheet_name = 'BankStatement_MA_NumReturnItems')
#   data[data['Credit_Score__c'].isna()].to_excel(writer, sheet_name = 'Credit_Score__c')
#   data[data['Renewal_PreviousPace'].isna()].to_excel(writer, sheet_name = 'Renewal_PreviousPace')

# %% [markdown]
# # WriteOff_YN

# %%
data['WriteOff_YN'].value_counts()
# Out:
# 0.0    373
# 1.0    115
# Name: WriteOff_YN, dtype: int64

# %%
data['WriteOff_YN'].isna().sum()
# Out:
# 0

# %%
data[data['WriteOff_YN'].isna()]['WriteOff_YN']
# Out:
# Series([], Name: WriteOff_YN, dtype: float64)

# %%
#data.drop(index=[3138, 3139], inplace = True)

# %%
data['WriteOff_YN'].isna().sum()
# Out:
# 0

# %%
# check for %_skewness
print("Percenatge of Non_writeoff_deal: ", round(data['WriteOff_YN'].value_counts()[0]/len(data['WriteOff_YN'])*100), "%")
print("Percenatge of writeoff_deal: ", round(data['WriteOff_YN'].value_counts()[1]/len(data['WriteOff_YN'])*100), "%")
# Out:
# Percenatge of Non_writeoff_deal:  76 %
# Percenatge of writeoff_deal:  24 %

# %%
## Dealing with the categorical attributes - converting them with one hot encoding methods

# %% [markdown]
# #### Is_this_Business_home_based__c
# #### Industry
# #### Drop_category

# %%
data = pd.get_dummies(data, columns = ['Is_this_Business_home_based__c'],drop_first= True)
data = pd.get_dummies(data, columns = ["Industry"], drop_first = True)
data = pd.get_dummies(data, columns = ["Drop_category"], drop_first = True)

# %% [markdown]
# # Renewal_PreviousPace

# %%
data[data['Renewal_PreviousPace'].isna()]['Renewal_PreviousPace'] #fill this up
# Out:
# 49    NaN
# 212   NaN
# Name: Renewal_PreviousPace, dtype: float64

# %%
data[data['Renewal_PreviousPace'] < 30][['Renewal_PreviousPace',"WriteOff_YN", "OpportunityID"]]
# Out:
#      Renewal_PreviousPace  WriteOff_YN       OpportunityID
# 110                 10.04          0.0  0062M00000o9rEEQAY
# 223                 23.22          1.0  0062M00000oBctkQAC

# %%
data.drop(index=[110,223], inplace = True)

# %%
data[data['Renewal_PreviousPace'] < 30]['Renewal_PreviousPace']
# Out:
# Series([], Name: Renewal_PreviousPace, dtype: float64)

# %%
# data[data['Renewal_PreviousPace'] < 50][['Renewal_PreviousPace', 'OpportunityID']].to_excel('/content/drive/MyDrive/anomalies_pace_rate.xlsx', index = True)

# %% [markdown]
# #### Time_in_Business__c - cheking -ve values

# %%
data[data["Time_in_Business__c"]<0]["Time_in_Business__c"]
# Out:
# Series([], Name: Time_in_Business__c, dtype: float64)

# %%
#data["Time_in_Business__c"] = data["Time_in_Business__c"].replace([-0.52,-0.85, -0.12, -1.07, -0.91, -0.72, -0.08, -0.06, -0.65, -0.37, -0.24], data["Time_in_Business__c"].median())

# %% [markdown]
# #### WOGross_AdvanceBalance
#
#
# 1.   Look for -ve values and replace them with zero

# %%
data['WOGross_AdvanceBalance'].describe()
# Out:
# count       486.000000
# mean       3948.086461
# std       18147.717532
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max      344226.190000
# Name: WOGross_AdvanceBalance, dtype: float64

# %%
data[data['WOGross_AdvanceBalance'] > 0]['WOGross_AdvanceBalance']
# Out:
# 5      344226.19
# 7       30839.75
# 8        6672.00
# 10      14354.45
# 13      12091.14
#          ...
# 465     65577.24
# 472     17164.73
# 479      2881.08
# 480     91386.70
# 482     14023.55
# Name: WOGross_AdvanceBalance, Length: 114, dtype: float64

# %%
data[(data['WOGross_AdvanceBalance'] < 0) & data['WriteOff_YN'] == 1][['WOGross_AdvanceBalance', 'WriteOff_YN']][:10]
# Out:
# Empty DataFrame
# Columns: [WOGross_AdvanceBalance, WriteOff_YN]
# Index: []

# %%
# Thesre are technically the anomalies - need to treat them differently at the decile time 
data[(data['WOGross_AdvanceBalance'] == 0) & data['WriteOff_YN'] == 1][['WOGross_AdvanceBalance', 'FundedWriteOffAmount_Gross', 'WriteOff_YN']]
# Out:
# Empty DataFrame
# Columns: [WOGross_AdvanceBalance, FundedWriteOffAmount_Gross, WriteOff_YN]
# Index: []

# %%
len(data[(data['WOGross_AdvanceBalance'] == 0) & data['WriteOff_YN'] == 1][['WOGross_AdvanceBalance', 'WriteOff_YN']])
# Out:
# 0

# %%
data[data['WOGross_AdvanceBalance'] < 0]['WOGross_AdvanceBalance']
# Out:
# Series([], Name: WOGross_AdvanceBalance, dtype: float64)

# %%
data[data['WOGross_AdvanceBalance'] < 0]['WriteOff_YN'].value_counts()
# Out:
# Series([], Name: WriteOff_YN, dtype: int64)

# %%
data[(data['WOGross_AdvanceBalance'] > 0) & data['WriteOff_YN'] == 1][['WOGross_AdvanceBalance', 'WriteOff_YN']]
# Out:
#      WOGross_AdvanceBalance  WriteOff_YN
# 5                 344226.19          1.0
# 7                  30839.75          1.0
# 8                   6672.00          1.0
# 10                 14354.45          1.0
# 13                 12091.14          1.0
# ..                      ...          ...
# 465                65577.24          1.0
# 472                17164.73          1.0
# 479                 2881.08          1.0
# 480                91386.70          1.0
# 482                14023.55          1.0
#
# [114 rows x 2 columns]

# %%
data[data["WOGross_AdvanceBalance"] > 0]["WriteOff_YN"].value_counts()
# Out:
# 1.0    114
# Name: WriteOff_YN, dtype: int64

# %%
# replacing -ve values with zeros
# data['WOGross_AdvanceBalance'] = data['WOGross_AdvanceBalance'].apply(lambda x: 0 if x < 0 else x)

# %%
data[data['WOGross_AdvanceBalance'] == 0]['WriteOff_YN'].value_counts()
# Out:
# 0.0    372
# Name: WriteOff_YN, dtype: int64

# %%
'''
funded_amount = $1000
payback_amount = $1500
collected_amount = $800 || $1200 || $1500 (extra $200)
adv_wos_$ (opp_1) = $1500 - $800 = $700
adv_wos_$ (opp_1) = $1500 - $1200 = $300
adv_wos_$ (opp_1) = $1500 - ($1500 + $200) = -$200
'''

# %%
data[(data['WOGross_AdvanceBalance'] == 0) & (data['WriteOff_YN'] == 1)][["OpportunityID", "WOGross_AdvanceBalance", "WriteOff_YN"]]
# Out:
# Empty DataFrame
# Columns: [OpportunityID, WOGross_AdvanceBalance, WriteOff_YN]
# Index: []

# %%
#data[(data['WOGross_AdvanceBalance'] == 0) & (data['WriteOff_YN'] == 1)][["OpportunityID", "WOGross_AdvanceBalance", "WriteOff_YN"]].index

# %%
'''
data.drop(index= [38,  163,  208,  274,  803,  814,  822,  892,  949, 1310, 1422,
            1493, 1503, 1561, 1675, 1745, 2242, 2353, 2356, 2378, 2408, 2436,
            2481, 2490, 2534, 2639, 2682, 2706, 2740, 2779, 2911, 2986, 3135], inplace = True)
'''

# %% [markdown]
# #### BBC_Position__C

# %%
data['BBC_Position__c']
# Out:
# 0      1.0
# 1      3.0
# 2      1.0
# 3      2.0
# 4      1.0
#       ...
# 483    1.0
# 484    1.0
# 485    1.0
# 486    2.0
# 487    2.0
# Name: BBC_Position__c, Length: 486, dtype: float64

# %%
data['BBC_Position__c'].value_counts()
# Out:
# 1.0    247
# 2.0    119
# 3.0     68
# 4.0     32
# 5.0     16
# 6.0      3
# 7.0      1
# Name: BBC_Position__c, dtype: int64

# %%
data['BBC_Position__c'].describe()
# Out:
# count    486.000000
# mean       1.897119
# std        1.161989
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        7.000000
# Name: BBC_Position__c, dtype: float64

# %%
data['BBC_Position__c'].isna().sum()
# Out:
# 0

# %%
data[data['BBC_Position__c'] < 0]['BBC_Position__c']
# Out:
# Series([], Name: BBC_Position__c, dtype: float64)

# %% [markdown]
# # NumberOfBankStatements

# %%
# Related attributes -

# AvgMonthRevenue - column name updated
# Renewal_PreviousAvgMonthRevenue
# AvgDailyBalance - column name updated
# Renewal_PreviousAvgDailyBalance
# BankStatement_MA_OverdraftDays
# BankStatement_MA_NumReturnItems
# Avg_ReturnItemsDays - column name updated
# Pct change in Month Revenue  - column name updated
# PctAvgDailybalance2AvgMonthlyRevenue - column name updated
# LastBankStatement_OverdraftDays - dropped
# BankStatement_Sum_NumReturnItems - dropped

# %%
data.columns
# Out:
# Index(['OpportunityID', 'Renewal_PreviousPace',
#        'Renewal_PreviousPaidPercentageOfRTR', 'Renewal_CountPreviousDeals',
#        'Renewal_PreviousCountBounces', 'Renewal_PreviousPosition',
#        'Renewal_PreviousHBwLCF', 'Renewal_PreviousAvgMonthRevenue',
#        'Renewal_PreviousAvgDailyBalance', 'Renewal_TwoWeekBounces',
#        'NumberOfBankStatements', 'Credit_Score__c', 'Time_in_Business__c',
#        'BBC_Position__c', 'HB_with_LCF_Payment__c',
#        'Last3Statments_MA_AdjustedMonthlyDeposits',
#        'Last3Statments_MA_AvgDailyBalance', 'Last3Statments_MA_ReturnItemDays',
#        'Last3Statments_MA_OverdraftDays', 'Last3Statments_MA_NumReturnItems',
#        'Last3Statments_Sum_NumReturnItems', 'FundedAmount', 'Paybackamount',
#        'WriteOff_YN', 'FundedWriteOffAmount_Gross', 'WOGross_AdvanceBalance',
#        'Avg_ReturnItemdays', 'LatestMonth_ReturnItemDays',
#        'PctChangeInReveune', 'PctAvgDailybalance2AvgMonthlyDeposits',
#        'TwoMonthAvg_AdjustedMonthlyDeposits', 'AdjustedMonthlyDeposits',
#        'drop_percent', 'Is_this_Business_home_based__c_Yes',
#        'Industry_Construction', 'Industry_Finance, Insurance, Real Estate',
#        'Industry_Manufacturing', 'Industry_Mining', 'Industry_Retail',
#        'Industry_Services', 'Industry_Transportation & Public Utilities',
#        'Industry_Wholesale', 'Drop_category_Positive'],
#       dtype='object')

# %%
def attribute_info(df_feature):
  print('Description of attribute :', '\n' )
  print(df_feature.describe(), '\n')
  print('Value counts of attribute :', '\n' )
  print(df_feature.value_counts(), '\n')
  print('Unique number of attribute :', '\n' )
  print(df_feature.unique(), '\n')
  print('Missing values in attribute :', '\n' )
  print(df_feature.isna().sum(), '\n')
  print('Missing values in attribute_% :', '\n' )
  print(df_feature.isna().sum()/len(df_feature)*100, '\n')
  plt.figure(figsize=(20,10))
  plt.subplot(2,2,1)
  sns.distplot(df_feature)
  plt.subplot(2,2,2)
  sns.boxplot(df_feature)
  plt.show()

# %%
data.isnull().sum().sort_values(ascending = False)/len(data)*100
# Out:
# LatestMonth_ReturnItemDays                    50.205761
# PctChangeInReveune                             2.057613
# Credit_Score__c                                1.851852
# Renewal_PreviousAvgMonthRevenue                1.440329
# Renewal_PreviousAvgDailyBalance                1.440329
# Renewal_PreviousPaidPercentageOfRTR            0.411523
# Renewal_PreviousPace                           0.411523
# OpportunityID                                  0.000000
# Is_this_Business_home_based__c_Yes             0.000000
# Avg_ReturnItemdays                             0.000000
# PctAvgDailybalance2AvgMonthlyDeposits          0.000000
# TwoMonthAvg_AdjustedMonthlyDeposits            0.000000
# AdjustedMonthlyDeposits                        0.000000
# drop_percent                                   0.000000
# Industry_Finance, Insurance, Real Estate       0.000000
# Industry_Construction                          0.000000
# FundedWriteOffAmount_Gross                     0.000000
# Industry_Manufacturing                         0.000000
# Industry_Mining                                0.000000
# Industry_Retail                                0.000000
# Industry_Services                              0.000000
# Industry_Transportation & Public Utilities     0.000000
# Industry_Wholesale                             0.000000
# WOGross_AdvanceBalance                         0.000000
# FundedAmount                                   0.000000
# WriteOff_YN                                    0.000000
# Paybackamount                                  0.000000
# Renewal_CountPreviousDeals                     0.000000
# Renewal_PreviousCountBounces                   0.000000
# Renewal_PreviousPosition                       0.000000
# Renewal_PreviousHBwLCF                         0.000000
# Renewal_TwoWeekBounces                         0.000000
# NumberOfBankStatements                         0.000000
# Time_in_Business__c                            0.000000
# BBC_Position__c                                0.000000
# HB_with_LCF_Payment__c                         0.000000
# Last3Statments_MA_AdjustedMonthlyDeposits      0.000000
# Last3Statments_MA_AvgDailyBalance              0.000000
# Last3Statments_MA_ReturnItemDays               0.000000
# Last3Statments_MA_OverdraftDays                0.000000
# Last3Statments_MA_NumReturnItems               0.000000
# Last3Statments_Sum_NumReturnItems              0.000000
# Drop_category_Positive                         0.000000
# dtype: float64

# %%
missing_attributes = ['LatestMonth_ReturnItemDays', 
                      'PctChangeInReveune', 
                      'Renewal_PreviousAvgMonthRevenue',
                      'Renewal_PreviousAvgDailyBalance',
                      'Renewal_PreviousPaidPercentageOfRTR',                                           
                      'Credit_Score__c',                          
                      'Renewal_PreviousPace']    

for col in missing_attributes:
  print('\033[1m'+'attribute_name :', col+'\033[0m')
  attribute_info(data[col])
# Out:
# attribute_name : LatestMonth_ReturnItemDays
# Description of attribute :
#
# count    242.000000
# mean       1.140496
# std        2.742945
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max       20.000000
# Name: LatestMonth_ReturnItemDays, dtype: float64
#
# Value counts of attribute :
#
# 0.0     172
# 2.0      22
# 1.0      16
# 3.0       8
# 5.0       4
# 4.0       4
# 7.0       4
# 15.0      3
# 6.0       3
# 8.0       2
# 10.0      2
# 9.0       1
# 20.0      1
# Name: LatestMonth_ReturnItemDays, dtype: int64
#
# Unique number of attribute :
#
# [nan  2.  0.  5.  8. 15.  1.  4.  9.  6. 20.  3.  7. 10.]
#
# Missing values in attribute :
#
# 244
#
# Missing values in attribute_% :
#
# 50.20576131687243
# attribute_name : PctChangeInReveune
# Description of attribute :
#
# count    476.000000
# mean      -0.151509
# std        2.655107
# min      -56.591706
# 25%       -0.146232
# 50%        0.058612
# 75%        0.205769
# max        0.938015
# Name: PctChangeInReveune, dtype: float64
#
# Value counts of attribute :
#
# -0.836880    1
#  0.092091    1
# -0.506266    1
#  0.575065    1
# -1.872548    1
#             ..
#  0.298314    1
# -0.015293    1
# -0.157447    1
#  0.306493    1
#  0.080796    1
#    27087.52   23723.88 1814759.39    7210.46   15339.47   53246.09
#    16580.43    8429.37   24093.22   13842.5 ]
#
# Missing values in attribute :
#
# 7
#
# Missing values in attribute_% :
#
# 1.440329218106996
# attribute_name : Renewal_PreviousAvgDailyBalance
# Description of attribute :
#
# count       479.000000
# mean      12664.549248
# std       32295.729668
# min        -531.080000
# 25%        1845.875000
# 50%        3720.600000
# 75%        8674.190000
# max      319752.250000
# Name: Renewal_PreviousAvgDailyBalance, dtype: float64
#
# Value counts of attribute :
#
# 5650.71     2
# 946.55      2
# 3583.33     1
# 4257.08     1
# 37338.96    1
#            ..
# 7084.12     1
# 2081.78     1
# 17624.79    1
# 3939.35     1
# 2335.66     1
# Name: Renewal_PreviousAvgDailyBalance, Length: 477, dtype: int64
#
# Unique number of attribute :
#
# [ 3.5833300e+03  1.4187000e+03  6.5698500e+03  1.8515300e+03
#   4.1224600e+03  5.2441000e+02  1.2014200e+03  7.5572000e+03
#   4.2920800e+03  4.1762100e+03  1.7492900e+03  1.7157200e+03
#             nan  7.8370300e+03  2.7092900e+03 -1.8535000e+02
#   1.2951650e+04  1.1433040e+04  2.1749670e+04  1.1741533e+05
#   9.2764000e+03  6.5525000e+02  3.1975225e+05  2.3557680e+04
#   2.3414610e+04  1.2094260e+04  2.3759900e+04  6.2047900e+03
#   1.4002500e+03  2.2616000e+03  7.9743200e+03  4.0781700e+03
#   4.0887000e+03  2.2930480e+04  1.8899310e+04  7.0848000e+02
#   1.6094500e+03  2.1677700e+03  2.1726710e+04  1.4926500e+03
#   6.1626700e+03  4.8234800e+03  6.6073900e+03  1.2713280e+05
#   2.6427800e+03  3.1417900e+03  2.0433000e+02  2.2121500e+03
#   4.1605300e+03  2.1002300e+03  1.9768294e+05  4.3631900e+03
#   1.4269340e+04  1.5277800e+03  1.6324100e+03  3.6735900e+03
#   2.5791000e+02  2.6171000e+03  1.1866600e+03  2.2498000e+03
#   8.7859000e+02  1.0100140e+04  1.3331030e+04  1.1067700e+03
#   7.8999000e+02  1.0744690e+04  4.3102550e+04  1.9606400e+03
#   3.0592000e+03  8.6077870e+04  2.3011310e+04  4.1166100e+03
#   5.9389300e+03 -1.2040000e+01 -3.9730000e+01  6.8434000e+02
#   1.2492680e+04  7.3062500e+03  1.9465120e+04  8.7048000e+02
#   2.3649000e+03  1.5156900e+03  1.3106370e+04  5.9567500e+03
#   4.0832900e+03  3.6916370e+04  3.4360900e+03  1.3504810e+04
#   8.3102000e+02  2.5246000e+03  8.4547200e+03  2.8617456e+05
#   7.9570000e+02  5.6453800e+03  3.6692410e+04  2.1664450e+04
#   5.6507100e+03  3.3658600e+03  4.7750000e+02  4.4802300e+03
#   3.2416100e+03  1.6185500e+04 -2.7666000e+02  2.7587500e+03
#   2.2979200e+03  1.6896600e+03  1.4378810e+04  2.5394800e+03
#   3.0641600e+03  9.1778800e+03  1.2814900e+03  6.0090000e+03
#   2.8390800e+03  7.8554900e+03  3.7502500e+03  1.1870290e+04
#   8.5977000e+03  1.9616600e+03  8.2010600e+03  5.6209100e+03
#   7.2544900e+03  1.1474180e+04  2.5553300e+03  2.4816900e+03
#   6.2848030e+04  1.1552000e+03  1.6010500e+03  5.1289800e+03
#   1.4821100e+03  9.9827100e+03  9.8419100e+03  2.0376370e+04
#   3.0022600e+03  6.4414700e+03  2.3887800e+03  5.9479000e+02
#   1.1743970e+04  5.3563600e+03  1.8946600e+03  2.8444200e+03
#   8.1808900e+03  1.8693900e+03  2.2653900e+03  2.0611400e+03
#   3.1728900e+03  2.0522600e+03  1.3692590e+04  8.1277400e+03
#   3.6249800e+03  2.3318500e+03  2.4028650e+04  9.2846700e+03
#   1.5200700e+03  1.6029600e+03  2.8459100e+03  8.2017000e+02
#   4.7509700e+03  2.3356600e+03]
#
# Missing values in attribute :
#
# 7
#
# Missing values in attribute_% :
#
# 1.440329218106996
# attribute_name : Renewal_PreviousPaidPercentageOfRTR
# Description of attribute :
#
# count    484.000000
# mean       0.746818
# std        0.281179
# min        0.070000
# 25%        0.530000
# 50%        0.650000
# 75%        1.000000
# max        2.130000
# Name: Renewal_PreviousPaidPercentageOfRTR, dtype: float64
#
# Value counts of attribute :
#
# 1.00    67
# 0.52    31
# 0.51    24
# 0.56    21
# 0.60    19
#         ..
# 0.16     1
# 0.47     1
# 0.88     1
# 1.79     1
# 0.71     1
# Name: Renewal_PreviousPaidPercentageOfRTR, Length: 108, dtype: int64
#
# Unique number of attribute :
#
# [0.9  0.78 0.49 0.6  0.56 1.09 0.8  0.52 0.83 0.65 0.28 1.46 0.68 1.
#  1.03 0.86 0.91 0.81 0.74 0.57 0.7  0.37 0.92 0.54 0.58 0.47 0.34 0.5
#  0.87 0.53 0.51 1.08  nan 0.33 0.76 0.39 0.61 0.64 1.01 1.52 0.55 1.02
#  1.18 1.67 0.63 0.73 0.67 1.42 0.85 0.44 0.07 1.13 1.26 0.66 1.79 0.79
#  0.82 0.26 0.96 1.05 0.93 1.39 0.62 0.69 0.43 1.86 0.99 0.98 0.89 0.35
#  0.84 0.18 1.48 0.94 0.59 0.97 0.48 1.35 0.95 0.16 0.15 0.42 0.88 1.14
#  0.24 1.27 1.17 2.13 1.23 1.04 1.25 1.31 1.2  1.71 0.75 1.22 1.15 1.45
#  1.21 0.77 1.33 1.44 1.38 0.72 1.85 0.36 1.28 1.37 0.71]
#
# Missing values in attribute :
#
# 2
#
# Missing values in attribute_% :
#
# 0.411522633744856
# attribute_name : Credit_Score__c
# Description of attribute :
#
# count    477.000000
# mean     555.287212
# std      162.174675
# min        0.000000
# 25%      544.000000
# 50%      589.000000
# 75%      634.000000
# max      802.000000
# Name: Credit_Score__c, dtype: float64
#
# Value counts of attribute :
#
# 0.0      25
# 1.0       8
# 628.0     7
# 612.0     7
# 559.0     6
#          ..
# 468.0     1
# 446.0     1
# 536.0     1
# 645.0     1
# 455.0     1
# Name: Credit_Score__c, Length: 197, dtype: int64
#
# Unique number of attribute :
#
# [553. 539. 577. 761. 605. 692. 733. 729. 546. 599. 527. 563. 583. 659.
#  624. 590. 593. 566. 616. 510. 533. 678. 511. 618. 706. 561. 613.  nan
#  635. 602. 547.   1. 567. 710. 564. 589. 596. 607. 544. 555. 472. 572.
#  625. 559. 521. 653. 541. 654. 668. 446. 645. 595. 582. 570. 610. 628.
#  550. 520. 682. 568. 532. 612. 663.   0. 525. 658. 575. 554. 617. 666.
#  597. 578. 522. 586. 549. 622. 634. 543. 480. 592. 632. 551. 474. 604.
#  535. 492. 709. 667. 615. 647. 518. 642. 802. 542. 646. 649. 579. 477.
#  573. 608. 633. 528. 556. 571. 655. 569. 674. 603. 545. 611. 529. 580.
#  531. 516. 587. 623. 509. 600. 490. 741. 585. 606. 669. 565. 534. 560.
#  598. 677. 697. 661. 636. 711. 558. 629. 497. 671. 698. 651. 656. 536.
#  581. 468. 619. 688. 683. 641. 637. 526. 609. 548. 679. 687. 652. 638.
#  675. 621. 627. 523. 594. 714. 614. 738. 574. 704. 690. 665. 505. 588.
#  540. 562. 500. 684. 620. 576. 487. 670. 557. 601. 643. 482. 513. 705.
#  501. 742. 662. 499. 650. 755. 700. 644. 471. 475. 694. 517. 502. 673.
#  680. 455.]
#
# Missing values in attribute :
#
# 9
#
# Missing values in attribute_% :
#
# 1.8518518518518516
# attribute_name : Renewal_PreviousPace
# Description of attribute :
#
# count    484.000000
# mean      98.519876
# std        5.753772
# min       54.550000
# 25%      100.000000
# 50%      100.000000
# 75%      100.000000
# max      100.000000
# Name: Renewal_PreviousPace, dtype: float64
#
# Value counts of attribute :
#
# 100.00    433
# 98.33       1
# 91.65       1
# 98.82       1
# 91.16       1
# 69.70       1
# 90.00       1
# 60.04       1
# 97.62       1
# 96.99       1
# 99.83       1
# 75.11       1
# 91.89       1
# 86.05       1
# 98.59       1
# 72.64       1
# 54.55       1
# 96.30       1
# 95.27       1
# 59.05       1
# 93.33       1
# 95.65       1
# 77.26       1
# 86.79       1
# 95.55       1
# 69.84       1
# 98.67       1
# 84.45       1
# 82.35       1
# 87.80       1
# 86.08       1
# 76.32       1
# 79.50       1
# 90.40       1
# 74.42       1
# 72.02       1
# 88.89       1
# 95.91       1
# 70.59       1
# 93.75       1
# 93.94       1
# 93.34       1
# 94.18       1
# 69.32       1
# 83.33       1
# 92.16       1
# 85.00       1
# 98.48       1
# 94.38       1
# 89.86       1
# 69.03       1
# 97.44       1
# Name: Renewal_PreviousPace, dtype: int64
#
# Unique number of attribute :
#
# [100.    98.33  87.8   86.08  76.32  79.5     nan  90.4   74.42  72.02
#   88.89  95.91  70.59  82.35  93.75  93.34  94.18  69.32  83.33  92.16
#   85.    98.48  94.38  89.86  69.03  93.94  84.45  98.67  69.84  91.65
#   98.82  91.16  69.7   90.    60.04  97.62  96.99  99.83  75.11  91.89
#   86.05  98.59  72.64  54.55  96.3   95.27  59.05  93.33  95.65  77.26
#   86.79  95.55  97.44]
#
# Missing values in attribute :
#
# 2
#
# Missing values in attribute_% :
#
# 0.411522633744856

# %%
''' this is taken from training data and values are imputed here
LatestMonth_ReturnItemDays :                    0.0
PctChangeInReveune :                            0.0729781970417135
Renewal_PreviousAvgMonthRevenue :               25553.69
Renewal_PreviousAvgDailyBalance :               3535.52
PctAvgDailybalance2AvgMonthlyDeposits :         0.1180997501225475
Avg_ReturnItemdays :                            0.0
Last3Statments_MA_ReturnItemDays :              0.0
Last3Statments_MA_AvgDailyBalance :             3552.718333
Last3Statments_MA_AdjustedMonthlyDeposits :     29361.903333000002
Renewal_PreviousPaidPercentageOfRTR :           0.67
AdjustedMonthlyDeposits :                       29157.7
Renewal_PreviousPace :                          100.0
drop_percent :                                  -5.3351845
TwoMonthAvg_AdjustedMonthlyDeposits :           30667.489230500003
'''

# %%
data['LatestMonth_ReturnItemDays'].fillna(0.0, inplace = True)
data['PctChangeInReveune'].fillna(0.072, inplace = True)
data['Credit_Score__c'].fillna(585.94, inplace = True)        
data['Renewal_PreviousAvgMonthRevenue'].fillna(25553.69, inplace = True)
data['Renewal_PreviousAvgDailyBalance'].fillna(3535.52, inplace = True)
data['Renewal_PreviousPaidPercentageOfRTR'].fillna(0.67, inplace = True)
data['Renewal_PreviousPace'].fillna(100.0, inplace = True)

# %%
data.isnull().sum().sort_values(ascending = False)/len(data)*100
# Out:
# OpportunityID                                 0.0
# drop_percent                                  0.0
# FundedWriteOffAmount_Gross                    0.0
# WOGross_AdvanceBalance                        0.0
# Avg_ReturnItemdays                            0.0
# LatestMonth_ReturnItemDays                    0.0
# PctChangeInReveune                            0.0
# PctAvgDailybalance2AvgMonthlyDeposits         0.0
# TwoMonthAvg_AdjustedMonthlyDeposits           0.0
# AdjustedMonthlyDeposits                       0.0
# Is_this_Business_home_based__c_Yes            0.0
# Paybackamount                                 0.0
# Industry_Construction                         0.0
# Industry_Finance, Insurance, Real Estate      0.0
# Industry_Manufacturing                        0.0
# Industry_Mining                               0.0
# Industry_Retail                               0.0
# Industry_Services                             0.0
# Industry_Transportation & Public Utilities    0.0
# Industry_Wholesale                            0.0
# WriteOff_YN                                   0.0
# FundedAmount                                  0.0
# Renewal_PreviousPace                          0.0
# NumberOfBankStatements                        0.0
# Renewal_PreviousPaidPercentageOfRTR           0.0
# Renewal_CountPreviousDeals                    0.0
# Renewal_PreviousCountBounces                  0.0
# Renewal_PreviousPosition                      0.0
# Renewal_PreviousHBwLCF                        0.0
# Renewal_PreviousAvgMonthRevenue               0.0
# Renewal_PreviousAvgDailyBalance               0.0
# Renewal_TwoWeekBounces                        0.0
# Credit_Score__c                               0.0
# Last3Statments_Sum_NumReturnItems             0.0
# Time_in_Business__c                           0.0
# BBC_Position__c                               0.0
# HB_with_LCF_Payment__c                        0.0
# Last3Statments_MA_AdjustedMonthlyDeposits     0.0
# Last3Statments_MA_AvgDailyBalance             0.0
# Last3Statments_MA_ReturnItemDays              0.0
# Last3Statments_MA_OverdraftDays               0.0
# Last3Statments_MA_NumReturnItems              0.0
# Drop_category_Positive                        0.0
# dtype: float64

# %%
data.to_excel('/content/drive/MyDrive/LCF_Internal/Renewable_Model/EDA Approach-1/XGBoost Implementation/v10/v10_after_eda_test_bankst.6.xlsx', index = False)
