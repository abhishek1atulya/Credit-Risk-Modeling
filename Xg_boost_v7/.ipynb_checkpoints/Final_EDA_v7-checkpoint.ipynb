# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_excel("/content/drive/MyDrive/LCF_Internal/Renewable_Model/EDA Approach-1/XGBoost Implementation/xgboost_v7/V7_data.xlsx")
data.head()
# Out:
#         OpportunityID         CreatedDate FundedDate  \
# 0  0062M00000cpFWPQA2 2019-01-28 19:29:49 2019-01-30
# 1  0062M00000ePQ19QAG 2019-04-29 14:04:49 2019-05-01
# 2  0062M00000gaIhxQAE 2019-08-08 15:04:27 2019-08-27
# 3  0062M00000jyFYmQAM 2020-06-03 20:29:09 2020-06-05
# 4  0062M00000bnZm0QAE 2019-01-16 21:18:40 2019-01-18
#
#                                    OpportunityName     Priordeal_OppID  \
# 0  Williams Auto Care Center-Renewal Deal-01282019  0064100000VmaReAAJ
# 1  Williams Auto Care Center-Renewal Deal-04292019  0062M00000cpFWPQA2
# 2  Williams Auto Care Center-Renewal Deal-08082019  0062M00000ePQ19QAG
# 3            JHG Enterprises-Renewal Deal-06032020  0062M00000jKYRJQA4
# 4    Wynmark Freight Systems-Renewal Deal-01162019  0062M00000bmkwJQAQ
#
#   Renewal_PreviousCollectionStatus  Renewal_PreviousPace  \
# 0                            Other                   NaN
# 1                            Other                   NaN
# 2                            Other                   NaN
# 3                            Other                 100.0
# 4                            Other                 100.0
#
#    Renewal_PreviousPaidPercentageOfRTR  Renewal_PreviousCreditScore  \
# 0                                 0.80                        567.0
# 1                                 0.66                        576.0
# 2                                 0.77                        608.0
# 3                                  NaN                        654.0
# 4                                 1.11                        465.0
#
#    Renewal_CountPreviousDeals  ...  WriteOff_YN  FundedWriteOffAmount_Gross  \
# 0                           1  ...            0                         NaN
# 1                           2  ...            0                         NaN
# 2                           3  ...            0                         NaN
# 3                           3  ...            0                         NaN
# 4                           1  ...            1                      1232.0
#
#    WOGross_AdvanceBalance   NetWO                           Industry  \
# 0                 8455.80     NaN                           Services
# 1                 5978.43     NaN                           Services
# 2                 -481.52     NaN                           Services
# 3                    0.00     NaN                           Services
# 4                 2212.00  1232.0  Transportation & Public Utilities
#
#                                    Industry_Group__c  Avg_ReturnItemdays  \
# 0      75 - Automotive Repair, Services, and Parking            2.333333
# 1      75 - Automotive Repair, Services, and Parking            5.000000
# 2      75 - Automotive Repair, Services, and Parking           12.000000
# 3                             73 - Business Services            0.000000
# 4  42 - Motor Freight Transportation and Warehousing            0.000000
#
#    LatestMonth_ReturnItemDays  PctChangeInReveune  \
# 0                         4.0                 NaN
# 1                         5.0           -0.335832
# 2                        18.0            0.121287
# 3                         0.0           -1.019486
# 4                         NaN                 NaN
#
#    PctAvgDailybalance2AvgMonthlyDeposits
# 0                              -0.000193
# 1                              -0.005570
# 2                              -0.009292
# 3                               0.695871
# 4                               0.042922
#
# [5 rows x 45 columns]

# %%
data.shape
# Out:
# (3138, 45)

# %%
data['ActiveDeal_YN'].value_counts()
# Out:
# 0    3091
# 1      47
# Name: ActiveDeal_YN, dtype: int64

# %%
data[data['ActiveDeal_YN'] == 1][['ActiveDeal_YN', 'WriteOff_YN', 'OpportunityID']][:20]
# Out:
#       ActiveDeal_YN  WriteOff_YN       OpportunityID
# 307               1            0  0062M00000nqEQIQA2
# 309               1            0  0062M00000nXt6ZQAS
# 328               1            0  0062M00000nG55ZQAS
# 337               1            0  0062M00000nn6QMQAY
# 350               1            0  0062M00000nWu2XQAS
# 351               1            0  0062M00000nYcpCQAS
# 470               1            0  0062M00000nXuCZQA0
# 518               1            0  0062M00000mzwXHQAY
# 522               1            0  0062M00000nnDjAQAU
# 803               1            0  0062M00000nn4RbQAI
# 818               1            0  0062M00000nqKPSQA2
# 824               1            0  0062M00000nYCdiQAG
# 1021              1            0  0062M00000nFoLUQA0
# 1102              1            0  0062M00000npsIiQAI
# 1138              1            0  0062M00000mUEP7QAO
# 1140              1            0  0062M00000nqI0DQAU
# 1165              1            0  0062M00000npiTpQAI
# 1225              1            0  0062M00000np719QAA
# 1317              1            0  0062M00000nqEW2QAM
# 1410              1            0  0062M00000o7yiwQAA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3138 entries, 0 to 3137
# Data columns (total 45 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   OpportunityID                          3138 non-null   object
#  1   CreatedDate                            3138 non-null   datetime64[ns]
#  2   FundedDate                             3138 non-null   datetime64[ns]
#  3   OpportunityName                        3138 non-null   object
#  4   Priordeal_OppID                        3138 non-null   object
#  5   Renewal_PreviousCollectionStatus       3138 non-null   object
#  6   Renewal_PreviousPace                   3128 non-null   float64
#  7   Renewal_PreviousPaidPercentageOfRTR    2515 non-null   float64
#  8   Renewal_PreviousCreditScore            3103 non-null   float64
#  9   Renewal_CountPreviousDeals             3138 non-null   int64
#  10  Renewal_PreviousCountBounces           3138 non-null   int64
#  11  Renewal_PreviousPosition               3138 non-null   int64
#  12  Renewal_PreviousHBwLCF                 3138 non-null   float64
#  13  Renewal_PreviousHBwoLCF                1924 non-null   float64
#  14  Renewal_PreviousAvgMonthRevenue        2627 non-null   float64
#  15  Renewal_PreviousAvgDailyBalance        2627 non-null   float64
#  16  Renewal_TwoWeekBounces                 3138 non-null   int64
#  17  NumberOfBankStatements                 3138 non-null   int64
#  18  BankStatement_MA_OverdraftDays         3053 non-null   float64
#  19  BankStatement_MA_NumReturnItems        3053 non-null   float64
#  20  BankStatement_Sum_NumReturnItems       3053 non-null   float64
#  21  LastBankStatement_OverdraftDays        2260 non-null   float64
#  22  Credit_Score__c                        3119 non-null   float64
#  23  Time_in_Business__c                    3137 non-null   float64
#  24  Is_this_Business_home_based__c         3137 non-null   object
#  25  BBC_Position__c                        3138 non-null   int64
#  26  HB_with_LCF_Payment__c                 3138 non-null   float64
#  27  HBwoLCF                                1515 non-null   float64
#  28  Contract_HoldBack__c                   3138 non-null   int64
#  29  AvgMonthlydeposits                     3053 non-null   float64
#  30  AvgDailybalance                        3053 non-null   float64
#  31  FundedAmount                           3138 non-null   float64
#  32  Paybackamount                          3138 non-null   float64
#  33  NewDeal_YN                             3138 non-null   int64
#  34  ActiveDeal_YN                          3138 non-null   int64
#  35  WriteOff_YN                            3138 non-null   int64
#  36  FundedWriteOffAmount_Gross             807 non-null    float64
#  37  WOGross_AdvanceBalance                 3138 non-null   float64
#  38  NetWO                                  807 non-null    float64
#  39  Industry                               3138 non-null   object
#  40  Industry_Group__c                      3138 non-null   object
#  41  Avg_ReturnItemdays                     3053 non-null   float64
#  42  LatestMonth_ReturnItemDays             2418 non-null   float64
#  43  PctChangeInReveune                     2566 non-null   float64
#  44  PctAvgDailybalance2AvgMonthlyDeposits  3052 non-null   float64
# dtypes: datetime64[ns](2), float64(26), int64(10), object(7)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#        Renewal_PreviousPace  Renewal_PreviousPaidPercentageOfRTR  \
# count           3128.000000                          2515.000000
# mean              98.440556                             0.675586
# std                6.722148                             0.215038
# min                0.000000                             0.000000
# 25%              100.000000                             0.540000
# 50%              100.000000                             0.620000
# 75%              100.000000                             0.780000
# max              100.000000                             2.150000
#
#        Renewal_PreviousCreditScore  Renewal_CountPreviousDeals  \
# count                  3103.000000                 3138.000000
# mean                    547.020303                    2.182282
# std                     156.332116                    1.699044
# min                       0.000000                    1.000000
# 25%                     529.000000                    1.000000
# 50%                     577.000000                    2.000000
# 75%                     622.000000                    3.000000
# max                     815.000000                   14.000000
#
#        Renewal_PreviousCountBounces  Renewal_PreviousPosition  \
# count                   3138.000000               3138.000000
# mean                       2.952199                  2.008604
# std                        7.593910                  1.330447
# min                        0.000000                  1.000000
# 25%                        0.000000                  1.000000
# 50%                        0.000000                  2.000000
# 75%                        2.000000                  3.000000
# max                       83.000000                 15.000000
#
#        Renewal_PreviousHBwLCF  Renewal_PreviousHBwoLCF  \
# count             3138.000000              1924.000000
# mean                31.346660                18.148170
# std                216.565559                58.131698
# min                  0.000000                 0.000000
# 25%                  8.492500                 0.000000
# 50%                 19.445000                 4.000000
# 75%                 33.437500                25.000000
# max              11539.840000              2098.000000
#
#        Renewal_PreviousAvgMonthRevenue  Renewal_PreviousAvgDailyBalance  ...  \
# count                     2.627000e+03                     2.627000e+03  ...
# mean                      6.529551e+04                     1.088657e+04  ...
# std                       3.015814e+05                     6.735781e+04  ...
# min                      -3.078490e+03                    -1.375330e+05  ...
# 25%                       1.379536e+04                     1.497825e+03  ...
# 50%                       2.475937e+04                     3.383130e+03  ...
# 75%                       5.022032e+04                     7.668050e+03  ...
# max                       1.241704e+07                     3.129067e+06  ...
#
#         NewDeal_YN  ActiveDeal_YN  WriteOff_YN  FundedWriteOffAmount_Gross  \
# count  3138.000000    3138.000000  3138.000000                  807.000000
# mean      0.079669       0.014978     0.257170                 9041.109913
# std       0.270823       0.121483     0.437144                23279.518626
# min       0.000000       0.000000     0.000000                    0.000000
# 25%       0.000000       0.000000     0.000000                  824.500000
# 50%       0.000000       0.000000     0.000000                 3530.000000
# 75%       0.000000       0.000000     1.000000                 8273.500000
# max       1.000000       1.000000     1.000000               317759.340000
#
#        WOGross_AdvanceBalance          NetWO  Avg_ReturnItemdays  \
# count             3138.000000     807.000000         3053.000000
# mean              9433.430102    7384.433197            0.942974
# std              31824.892162   20633.318421            2.256977
# min            -102606.990000       0.000000            0.000000
# 25%                  0.000000       0.000000            0.000000
# 50%               3378.100000    2007.590000            0.000000
# 75%               8838.632500    7017.720000            0.666666
# max             700000.000000  317759.340000           34.000000
#
#        LatestMonth_ReturnItemDays  PctChangeInReveune  \
# count                 2418.000000         2566.000000
# mean                     1.300662           -4.877842
# std                      2.966397          186.532273
# min                      0.000000        -9273.441572
# 25%                      0.000000           -0.181559
# 50%                      0.000000            0.081810
# 75%                      1.000000            0.316836
# max                     34.000000            7.308505
#
#        PctAvgDailybalance2AvgMonthlyDeposits
# count                            3052.000000
# mean                                0.304964
# std                                 3.858320
# min                                -0.272989
# 25%                                 0.060214
# 50%                                 0.115120
# 75%                                 0.211559
# max                               205.822636
#
# [8 rows x 36 columns]

# %% [markdown]
# # Tasks to do
#
# 1. Perform EDA - **Done**
# 2. check wos - remove missing but give in excel sheet - **Done**
# 3. Specifically take care of no of bank statements and all other attributes related to it - **Done**
# 4. Check again the pace rates - {check for extreme weird values} - **Done**
# 5. Check for anomalies - **Done**
# 6. is this business home based - take care - **Done**
# 7. take care of features to be dropped - take previous references - **Done**
# 8. fill the missing values - so as to keep the progress alive - **Done**
# 9. EDA is completed - save the file
# 10. Model Training
# * Original attributes
# * Sub features
# * with new_features

# %%
numerical_attributes = data.columns[data.dtypes!="object"]
categorical_attributes = data.columns[data.dtypes=="object"]
print("Numerical_attributes :", len(numerical_attributes), "\n")
print(numerical_attributes)
print('\n')
print("Categorical_attributes :", len(categorical_attributes), "\n")
print(categorical_attributes)
# Out:
# Numerical_attributes : 38
#
# Index(['CreatedDate', 'FundedDate', 'Renewal_PreviousPace',
#        'Renewal_PreviousPaidPercentageOfRTR', 'Renewal_PreviousCreditScore',
#        'Renewal_CountPreviousDeals', 'Renewal_PreviousCountBounces',
#        'Renewal_PreviousPosition', 'Renewal_PreviousHBwLCF',
#        'Renewal_PreviousHBwoLCF', 'Renewal_PreviousAvgMonthRevenue',
#        'Renewal_PreviousAvgDailyBalance', 'Renewal_TwoWeekBounces',
#        'NumberOfBankStatements', 'BankStatement_MA_OverdraftDays',
#        'BankStatement_MA_NumReturnItems', 'BankStatement_Sum_NumReturnItems',
#        'LastBankStatement_OverdraftDays', 'Credit_Score__c',
#        'Time_in_Business__c', 'BBC_Position__c', 'HB_with_LCF_Payment__c',
#        'HBwoLCF', 'Contract_HoldBack__c', 'AvgMonthlydeposits',
#        'AvgDailybalance', 'FundedAmount', 'Paybackamount', 'NewDeal_YN',
#        'ActiveDeal_YN', 'WriteOff_YN', 'FundedWriteOffAmount_Gross',
#        'WOGross_AdvanceBalance', 'NetWO', 'Avg_ReturnItemdays',
#        'LatestMonth_ReturnItemDays', 'PctChangeInReveune',
#        'PctAvgDailybalance2AvgMonthlyDeposits'],
#       dtype='object')
#
#
# Categorical_attributes : 7
#
# Index(['OpportunityID', 'OpportunityName', 'Priordeal_OppID',
#        'Renewal_PreviousCollectionStatus', 'Is_this_Business_home_based__c',
#        'Industry', 'Industry_Group__c'],
#       dtype='object')

# %%
data.shape
# Out:
# (3138, 45)

# %% [markdown]
# # Dropped the unwanted features

# %% [markdown]
# #### Attributes to be used later but not the part of the training -
# *  'FundedWriteOffAmount_Gross', 'FundedWriteOffAmount_Net',
# *  'Renewal_PreviousHBwoLCF'
# *  'Renewal_PreviousHBwLCF'

# %%
# Dropped unwanted features
data =  data.drop(['OpportunityName',
                   'Priordeal_OppID',
                   'CreatedDate',
                   'FundedDate',
                   'Industry',       
                   'Industry_Group__c',
                   'Renewal_PreviousCollectionStatus',
                   'ActiveDeal_YN',
                   'NewDeal_YN',
                   'Renewal_PreviousCreditScore',
                   'BankStatement_Sum_NumReturnItems',
                   'LastBankStatement_OverdraftDays',
                   'BBC_Position__c',
                   'HBwoLCF',
                   'Contract_HoldBack__c',
                   'Renewal_PreviousHBwoLCF'], axis=1)

# %%
data.shape
# Out:
# (3138, 29)

# %%
numerical_attributes = data.columns[data.dtypes!="object"]
categorical_attributes = data.columns[data.dtypes=="object"]
print("Numerical_attributes :", len(numerical_attributes), "\n")
print(numerical_attributes)
print('\n')
print("Categorical_attributes :", len(categorical_attributes), "\n")
print(categorical_attributes)
# Out:
# Numerical_attributes : 27
#
# Index(['Renewal_PreviousPace', 'Renewal_PreviousPaidPercentageOfRTR',
#        'Renewal_CountPreviousDeals', 'Renewal_PreviousCountBounces',
#        'Renewal_PreviousPosition', 'Renewal_PreviousHBwLCF',
#        'Renewal_PreviousAvgMonthRevenue', 'Renewal_PreviousAvgDailyBalance',
#        'Renewal_TwoWeekBounces', 'NumberOfBankStatements',
#        'BankStatement_MA_OverdraftDays', 'BankStatement_MA_NumReturnItems',
#        'Credit_Score__c', 'Time_in_Business__c', 'HB_with_LCF_Payment__c',
#        'AvgMonthlydeposits', 'AvgDailybalance', 'FundedAmount',
#        'Paybackamount', 'WriteOff_YN', 'FundedWriteOffAmount_Gross',
#        'WOGross_AdvanceBalance', 'NetWO', 'Avg_ReturnItemdays',
#        'LatestMonth_ReturnItemDays', 'PctChangeInReveune',
#        'PctAvgDailybalance2AvgMonthlyDeposits'],
#       dtype='object')
#
#
# Categorical_attributes : 2
#
# Index(['OpportunityID', 'Is_this_Business_home_based__c'], dtype='object')

# %% [markdown]
# # Checking Nan values

# %%
data.isnull().sum().sort_values(ascending = False)/len(data)*100
# Out:
# NetWO                                    74.282983
# FundedWriteOffAmount_Gross               74.282983
# LatestMonth_ReturnItemDays               22.944551
# Renewal_PreviousPaidPercentageOfRTR      19.853410
# PctChangeInReveune                       18.228171
# Renewal_PreviousAvgMonthRevenue          16.284257
# Renewal_PreviousAvgDailyBalance          16.284257
# PctAvgDailybalance2AvgMonthlyDeposits     2.740599
# AvgMonthlydeposits                        2.708732
# Avg_ReturnItemdays                        2.708732
# AvgDailybalance                           2.708732
# BankStatement_MA_OverdraftDays            2.708732
# BankStatement_MA_NumReturnItems           2.708732
# Credit_Score__c                           0.605481
# Renewal_PreviousPace                      0.318674
# Time_in_Business__c                       0.031867
# Is_this_Business_home_based__c            0.031867
# HB_with_LCF_Payment__c                    0.000000
# NumberOfBankStatements                    0.000000
# FundedAmount                              0.000000
# Paybackamount                             0.000000
# WriteOff_YN                               0.000000
# Renewal_TwoWeekBounces                    0.000000
# WOGross_AdvanceBalance                    0.000000
# Renewal_PreviousHBwLCF                    0.000000
# Renewal_PreviousPosition                  0.000000
# Renewal_PreviousCountBounces              0.000000
# Renewal_CountPreviousDeals                0.000000
# OpportunityID                             0.000000
# dtype: float64

# %% [markdown]
# ## ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# ###  Observations
#
# * Some attributes name updated, like -
#    - FundedWriteOffAmount_Net = NetWO
#    - AvgMonthRevenue = AvgMonthlydeposits
#    - AvgDailyBalance = AvgDailybalance
#    - Avg_ReturnItemsDays = Avg_ReturnItemdays
#    - Pct change in Month Revenue = PctChangeInReveune
#    - PctAvgDailybalance2AvgMonthlyRevenue = PctAvgDailybalance2AvgMonthlyDeposits
#
#
# * WriteOff_YN = No missing values
# * Is_this_Business_home_based__c = Categorical to Numerical
# * Renewal_PreviousPace = There are 10 values having less than 50% pace_rate and 10 nan values also
# * Time_in_Business__c = Included negative values

# %% [markdown]
# # New Columns added
#
# * Paybackamount
# * Priordeal_OppID
# * WOGross_AdvanceBalance
# * NetWO
# * AvgMonthlydeposits
# * FundedAmount

# %%
data.corr()['WriteOff_YN']
# Out:
# Renewal_PreviousPace                    -0.005827
# Renewal_PreviousPaidPercentageOfRTR     -0.074070
# Renewal_CountPreviousDeals              -0.083737
# Renewal_PreviousCountBounces             0.019357
# Renewal_PreviousPosition                 0.000579
# Renewal_PreviousHBwLCF                  -0.016076
# Renewal_PreviousAvgMonthRevenue          0.033364
# Renewal_PreviousAvgDailyBalance          0.026054
# Renewal_TwoWeekBounces                   0.053185
# NumberOfBankStatements                  -0.026291
# BankStatement_MA_OverdraftDays           0.046145
# BankStatement_MA_NumReturnItems          0.007169
# Credit_Score__c                         -0.059408
# Time_in_Business__c                     -0.108521
# HB_with_LCF_Payment__c                  -0.020569
# AvgMonthlydeposits                       0.007139
# AvgDailybalance                         -0.000708
# FundedAmount                             0.021570
# Paybackamount                            0.024125
# WriteOff_YN                              1.000000
# FundedWriteOffAmount_Gross                    NaN
# WOGross_AdvanceBalance                   0.186970
# NetWO                                         NaN
# Avg_ReturnItemdays                       0.018659
# LatestMonth_ReturnItemDays               0.039953
# PctChangeInReveune                      -0.029479
# PctAvgDailybalance2AvgMonthlyDeposits   -0.016675
# Name: WriteOff_YN, dtype: float64

# %% [markdown]
# # Tasks to do -
#
# * EDA -
# * -ves, replace it by 0    - WOGross_AdvanceBalance - **Done**
# * 1 outlier - remove it - **Done**
# * Pace rate - drop it <50%   - Renewal_PreviousPace - **Done**
# * check for sir answer - **Done**
# * decile analysis on and train data both
# * Contact us - to discuss hyper-parameter tuning

# %% [markdown]
# # WriteOff_YN

# %%
data['WriteOff_YN'].isna().sum()
# Out:
# 0

# %%
data['WriteOff_YN'].value_counts()
# Out:
# 0    2331
# 1     807
# Name: WriteOff_YN, dtype: int64

# %% [markdown]
# # Is_this_Business_home_based__c

# %%
data = pd.get_dummies(data,columns = ['Is_this_Business_home_based__c'],drop_first= True)

# %% [markdown]
# # Renewal_PreviousPace

# %%
data[data['Renewal_PreviousPace'].isna()]['Renewal_PreviousPace']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 818    NaN
# 1096   NaN
# 2473   NaN
# 2679   NaN
# 3017   NaN
# 3085   NaN
# 3106   NaN
# Name: Renewal_PreviousPace, dtype: float64

# %%
data[data['Renewal_PreviousPace'] < 50]['Renewal_PreviousPace']
# Out:
# 530     10.03
# 568     46.31
# 640     44.15
# 1221    12.00
# 1229    39.29
# 2903    42.80
# 2937     0.00
# 3036    35.71
# 3067    20.00
# 3120    19.93
# Name: Renewal_PreviousPace, dtype: float64

# %%
data.drop(index=[530, 568, 640, 1221, 1229, 2903, 2937, 3036, 3067, 3120], inplace = True)

# %%
data[data['Renewal_PreviousPace'] < 50]['Renewal_PreviousPace']
# Out:
# Series([], Name: Renewal_PreviousPace, dtype: float64)

# %%
# data[data['Renewal_PreviousPace'] < 50][['Renewal_PreviousPace', 'OpportunityID']].to_excel('/content/drive/MyDrive/anomalies_pace_rate.xlsx', index = True)

# %% [markdown]
# # Time_in_Business__c

# %%
data[data["Time_in_Business__c"]<0]["Time_in_Business__c"]
# Out:
# 94     -0.37
# 147    -0.52
# 325    -0.65
# 622    -0.06
# 869    -0.08
# 1739   -0.91
# 1894   -1.07
# 1908   -0.72
# 2688   -0.12
# 2911   -0.85
# 3059   -0.24
# Name: Time_in_Business__c, dtype: float64

# %%
data["Time_in_Business__c"].median()
# Out:
# 4.05

# %%
data["Time_in_Business__c"] = data["Time_in_Business__c"].replace([-0.52,-0.85, -0.12, -1.07, -0.91, -0.72, -0.08, -0.06, -0.65, -0.37, -0.24], data["Time_in_Business__c"].median())

# %%
data[data["Time_in_Business__c"]<0]["Time_in_Business__c"]
# Out:
# Series([], Name: Time_in_Business__c, dtype: float64)

# %% [markdown]
# # WOGross_AdvanceBalance

# %%
data.shape
# Out:
# (3127, 29)

# %%
data[data['WOGross_AdvanceBalance'] < 0]['WOGross_AdvanceBalance']
# Out:
# 2       -481.52
# 8      -1877.59
# 36     -2258.00
# 44      -315.00
# 48       -35.00
#          ...
# 3123     -70.00
# 3125     -35.00
# 3126    -966.00
# 3130    -652.10
# 3137    -175.00
# Name: WOGross_AdvanceBalance, Length: 617, dtype: float64

# %%
data[data['WOGross_AdvanceBalance'] < 0]['WriteOff_YN'].value_counts()
# Out:
# 0    585
# 1     32
# Name: WriteOff_YN, dtype: int64

# %%
data['WOGross_AdvanceBalance'] = data['WOGross_AdvanceBalance'].apply(lambda x: 0 if x < 0 else x)

# %%
data[data['WOGross_AdvanceBalance'] < 0]['WOGross_AdvanceBalance']
# Out:
# Series([], Name: WOGross_AdvanceBalance, dtype: float64)

# %%
data['WOGross_AdvanceBalance']
# Out:
# 0       8455.80
# 1       5978.43
# 2          0.00
# 3          0.00
# 4       2212.00
#          ...
# 3133       0.00
# 3134     302.50
# 3135       0.00
# 3136    3874.00
# 3137       0.00
# Name: WOGross_AdvanceBalance, Length: 3127, dtype: float64

# %%
data[data['WOGross_AdvanceBalance'] == 0]['WriteOff_YN'].value_counts()
# Out:
# 0    379
# 1      1
# Name: WriteOff_YN, dtype: int64

# %%
data[(data['WOGross_AdvanceBalance'] == 0) & (data['WriteOff_YN'] == 1)]
# Out:
#            OpportunityID  Renewal_PreviousPace  \
# 1356  0062M00000lw2hoQAA                 100.0
#
#       Renewal_PreviousPaidPercentageOfRTR  Renewal_CountPreviousDeals  \
# 1356                                  1.0                           2
#
#       Renewal_PreviousCountBounces  Renewal_PreviousPosition  \
# 1356                             0                         1
#
#       Renewal_PreviousHBwLCF  Renewal_PreviousAvgMonthRevenue  \
# 1356                   34.78                          9470.06
#
#       Renewal_PreviousAvgDailyBalance  Renewal_TwoWeekBounces  ...  \
# 1356                           143.36                       0  ...
#
#       Paybackamount  WriteOff_YN  FundedWriteOffAmount_Gross  \
# 1356        25560.0            1                         0.0
#
#       WOGross_AdvanceBalance  NetWO  Avg_ReturnItemdays  \
# 1356                     0.0    0.0                 0.0
#
#       LatestMonth_ReturnItemDays  PctChangeInReveune  \
# 1356                         0.0            0.570225
#
#       PctAvgDailybalance2AvgMonthlyDeposits  \
# 1356                               0.048838
#
#       Is_this_Business_home_based__c_Yes
# 1356                                   0
#
# [1 rows x 29 columns]

# %%
data.drop(index=[1356], inplace = True)

# %%
data[(data['WOGross_AdvanceBalance'] == 0) & (data['WriteOff_YN'] == 1)]
# Out:
# Empty DataFrame
# Columns: [OpportunityID, Renewal_PreviousPace, Renewal_PreviousPaidPercentageOfRTR, Renewal_CountPreviousDeals, Renewal_PreviousCountBounces, Renewal_PreviousPosition, Renewal_PreviousHBwLCF, Renewal_PreviousAvgMonthRevenue, Renewal_PreviousAvgDailyBalance, Renewal_TwoWeekBounces, NumberOfBankStatements, BankStatement_MA_OverdraftDays, BankStatement_MA_NumReturnItems, Credit_Score__c, Time_in_Business__c, HB_with_LCF_Payment__c, AvgMonthlydeposits, AvgDailybalance, FundedAmount, Paybackamount, WriteOff_YN, FundedWriteOffAmount_Gross, WOGross_AdvanceBalance, NetWO, Avg_ReturnItemdays, LatestMonth_ReturnItemDays, PctChangeInReveune, PctAvgDailybalance2AvgMonthlyDeposits, Is_this_Business_home_based__c_Yes]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# # NumberOfBankStatements

# %%
# Related attributes -

# AvgMonthRevenue - column name updated
# Renewal_PreviousAvgMonthRevenue
# AvgDailyBalance - column name updated
# Renewal_PreviousAvgDailyBalance
# BankStatement_MA_OverdraftDays
# BankStatement_MA_NumReturnItems
# Avg_ReturnItemsDays - column name updated
# Pct change in Month Revenue  - column name updated
# PctAvgDailybalance2AvgMonthlyRevenue - column name updated
# LastBankStatement_OverdraftDays - dropped
# BBC_Position__c - dropped
# BankStatement_Sum_NumReturnItems - dropped

# %%
data.columns
# Out:
# Index(['OpportunityID', 'Renewal_PreviousPace',
#        'Renewal_PreviousPaidPercentageOfRTR', 'Renewal_CountPreviousDeals',
#        'Renewal_PreviousCountBounces', 'Renewal_PreviousPosition',
#        'Renewal_PreviousHBwLCF', 'Renewal_PreviousAvgMonthRevenue',
#        'Renewal_PreviousAvgDailyBalance', 'Renewal_TwoWeekBounces',
#        'NumberOfBankStatements', 'BankStatement_MA_OverdraftDays',
#        'BankStatement_MA_NumReturnItems', 'Credit_Score__c',
#        'Time_in_Business__c', 'HB_with_LCF_Payment__c', 'AvgMonthlydeposits',
#        'AvgDailybalance', 'FundedAmount', 'Paybackamount', 'WriteOff_YN',
#        'FundedWriteOffAmount_Gross', 'WOGross_AdvanceBalance', 'NetWO',
#        'Avg_ReturnItemdays', 'LatestMonth_ReturnItemDays',
#        'PctChangeInReveune', 'PctAvgDailybalance2AvgMonthlyDeposits',
#        'Is_this_Business_home_based__c_Yes'],
#       dtype='object')

# %%
data['NumberOfBankStatements'].isna().sum()
# Out:
# 0

# %%
data['Renewal_PreviousAvgDailyBalance'].isna().sum()
# Out:
# 509

# %%
data['Renewal_PreviousAvgMonthRevenue'].isna().sum()
# Out:
# 509

# %%
data['AvgMonthlydeposits'].isna().sum()
# Out:
# 83

# %%
data['AvgDailybalance'].isna().sum()
# Out:
# 83

# %%
data['BankStatement_MA_NumReturnItems'].isna().sum()
# Out:
# 83

# %%
data['BankStatement_MA_OverdraftDays'].isna().sum()
# Out:
# 83

# %%
data['Avg_ReturnItemdays'].isna().sum()
# Out:
# 83

# %%
data['PctChangeInReveune'].isna().sum()
# Out:
# 569

# %%
data['PctAvgDailybalance2AvgMonthlyDeposits'].isna().sum()
# Out:
# 84

# %%
data.isnull().sum().sort_values(ascending = False)/len(data)*100
# Out:
# NetWO                                    74.352414
# FundedWriteOffAmount_Gross               74.352414
# LatestMonth_ReturnItemDays               22.865366
# Renewal_PreviousPaidPercentageOfRTR      19.699392
# PctChangeInReveune                       18.196354
# Renewal_PreviousAvgMonthRevenue          16.277582
# Renewal_PreviousAvgDailyBalance          16.277582
# PctAvgDailybalance2AvgMonthlyDeposits     2.686281
# Avg_ReturnItemdays                        2.654301
# AvgDailybalance                           2.654301
# AvgMonthlydeposits                        2.654301
# BankStatement_MA_OverdraftDays            2.654301
# BankStatement_MA_NumReturnItems           2.654301
# Credit_Score__c                           0.575632
# Renewal_PreviousPace                      0.319795
# Time_in_Business__c                       0.031980
# WOGross_AdvanceBalance                    0.000000
# Paybackamount                             0.000000
# WriteOff_YN                               0.000000
# OpportunityID                             0.000000
# FundedAmount                              0.000000
# HB_with_LCF_Payment__c                    0.000000
# NumberOfBankStatements                    0.000000
# Renewal_TwoWeekBounces                    0.000000
# Renewal_PreviousHBwLCF                    0.000000
# Renewal_PreviousPosition                  0.000000
# Renewal_PreviousCountBounces              0.000000
# Renewal_CountPreviousDeals                0.000000
# Is_this_Business_home_based__c_Yes        0.000000
# dtype: float64

# %%
def attribute_info(df_feature):
  print('Description of attribute :', '\n' )
  print(df_feature.describe(), '\n')
  print('Value counts of attribute :', '\n' )
  print(df_feature.value_counts(), '\n')
#   83.95  98.11  92.57  88.68  81.92  62.82  83.33  88.57  95.33  93.77
#   90.75  79.55  76.09  92.86  61.67  70.97  70.44  72.24  94.78  82.32
#   56.    96.69  75.85  99.84  93.57  95.44  97.56  67.14  65.94  96.02
#   95.35  64.65  93.22  67.93  87.16  95.03  96.3   84.31]
#
# Missing values in attribute :
#
# 10
#
# Missing values in attribute_% :
#
# 0.3197953309881676
# attribute_name : Renewal_PreviousPaidPercentageOfRTR
# Description of attribute :
#
# count    2511.000000
# mean        0.676014
# std         0.214361
# min         0.000000
# 25%         0.540000
# 50%         0.620000
# 75%         0.780000
# max         2.150000
# Name: Renewal_PreviousPaidPercentageOfRTR, dtype: float64
#
# Value counts of attribute :
#
# 0.52    119
# 0.53    117
# 0.51    104
# 0.60     99
# 0.56     90
#        ...
# 0.19      1
# 1.51      1
# 1.57      1
# 1.42      1
# 1.52      1
# Name: Renewal_PreviousPaidPercentageOfRTR, Length: 145, dtype: int64
#
# Unique number of attribute :
#
# [0.8  0.66 0.77  nan 1.11 0.97 0.63 0.82 0.88 0.13 0.33 0.75 0.6  0.55
#  0.94 1.16 0.61 0.93 0.84 0.51 1.5  0.58 0.62 0.65 0.7  0.52 0.64 1.04
#  1.25 0.85 1.   0.76 0.57 0.53 0.74 0.54 0.99 0.71 0.56 0.69 0.9  1.72
#  0.72 1.03 0.73 0.67 0.4  0.44 0.47 0.5  1.41 1.18 0.78 0.83 1.1  1.32
#  0.95 0.46 1.02 1.15 1.01 1.28 0.48 1.69 0.68 0.92 1.3  0.23 0.49 0.27
#  0.87 1.48 1.77 0.98 0.59 1.08 0.96 1.65 1.13 1.14 0.91 0.86 0.81 0.42
#  1.17 1.2  0.08 1.22 1.37 0.29 0.36 0.89 1.4  0.34 0.43 1.33 0.17 0.39
#  0.31 1.07 0.79 1.24 0.28 0.14 1.38 0.19 1.51 1.57 1.45 2.15 0.32 1.93
#  0.41 1.42 0.25 1.09 0.26 1.31 0.3  0.21 0.05 0.18 0.24 0.1  0.45 1.05
#  1.06 0.16 0.37 1.27 0.11 0.22 1.29 0.35 1.12 1.71 0.   0.12 1.34 0.2
#  0.38 1.76 0.15 1.39 1.36 1.52]
#
# Missing values in attribute :
#
# 616
#
# Missing values in attribute_% :
#
# 19.69939238887112
# attribute_name : Renewal_CountPreviousDeals
# Description of attribute :
#
# count    3127.000000
# mean        2.185801
# std         1.700838
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        14.000000
# Name: Renewal_CountPreviousDeals, dtype: float64
#
# Value counts of attribute :
#
# 1     1515
# 2      730
# 3      372
# 4      199
# 5      136
# 6       76
# 7       45
# 8       22
# 9       13
# 10      11
# 11       5
# 13       1
# 12       1
# 14       1
# Name: Renewal_CountPreviousDeals, dtype: int64
#
# Unique number of attribute :
#
# [ 1  2  3  6  7  4  5  8  9 10 11 13 12 14]
#
# Missing values in attribute :
#
# 0
#
# Missing values in attribute_% :
#
# 0.0
# attribute_name : Renewal_PreviousCountBounces
# Description of attribute :
#
# count    3127.000000
# mean        2.933802
# std         7.586888
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max        83.000000
# Name: Renewal_PreviousCountBounces, dtype: float64
#
# Value counts of attribute :
#
# 0     1936
# 1      271
# 2      181
# 3      138
# 4       94
# 5       80
# 6       46
# 7       43
# 8       31
# 9       29
# 10      24
# 12      23
# 11      22
# 14      16
# 15      15
# 16      13
# 20      13
# 17      11
# 13      11
# 18      10
# 24       8
# 21       8
# 25       7
# 36       7
# 27       6
# 28       6
# 29       6
# 32       6
# 22       6
# 23       5
# 19       5
# 26       4
# 30       4
# 35       4
# 61       3
# 54       3
# 43       3
# 42       3
# 33       3
# 49       2
# 38       2
# 56       2
# 34       2
# 75       1
# 52       1
# 79       1
# 78       1
# 83       1
# 44       1
# 48       1
# 55       1
# 45       1
# 60       1
# 37       1
# 41       1
# 63       1
# 31       1
# 47       1
# Name: Renewal_PreviousCountBounces, dtype: int64
#
# Unique number of attribute :
#
# [ 0  4  7  2 28  1  5 38 16 10  3  8 14 11 25 21 29 12 27  6 13 20 15  9
#  18 26 31 54 34 24 19 17 36 63 32 22 33 56 41 55 61 35 23 30 42 37 43 49
#  60 45 52 48 44 78 75 83 79 47]
#
# Missing values in attribute :
#
# 0
#
# Missing values in attribute_% :
#
# 0.0
# attribute_name : Renewal_PreviousPosition
# Description of attribute :
#
# count    3127.000000
# mean        2.007675
# std         1.330509
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        15.000000
# Name: Renewal_PreviousPosition, dtype: float64
#
# Value counts of attribute :
#
# 1     1468
# 2      845
# 3      410
# 4      263
# 5       78
# 6       39
# 7       11
# 9        3
# 10       3
# 8        2
# 13       2
# 15       1
# 12       1
# 11       1
# Name: Renewal_PreviousPosition, dtype: int64
#
# Unique number of attribute :
#
# [ 1  4  2  3  6  5  9  7  8 10 15 12 13 11]
#
# Missing values in attribute :
#
# 0
#
# Missing values in attribute_% :
#
# 0.0
# attribute_name : Renewal_PreviousHBwLCF
# Description of attribute :
#
# count     3127.000000
# mean        30.955136
# std        215.751904
# min          0.000000
# 25%          8.490000
# 50%         19.430000
# 75%         33.340000
# max      11539.840000
# Name: Renewal_PreviousHBwLCF, dtype: float64
#
# Value counts of attribute :
#
# 0.00     609
# 20.40      5
# 17.66      5
# 13.10      4
# 9.93       4
#         ...
# 25.90      1
# 60.23      1
# 28.08      1
# 13.92      1
# 36.98      1
# Name: Renewal_PreviousHBwLCF, Length: 2025, dtype: int64
#
# Unique number of attribute :
#
# [ 0.   41.95 44.6  ...  5.35 74.19 36.98]
#
# Missing values in attribute :
#
# 0
#
# Missing values in attribute_% :
#
# 0.0
# attribute_name : Renewal_PreviousAvgMonthRevenue
# Description of attribute :
#
# count    2.618000e+03
# mean     6.541885e+04
# std      3.020899e+05
# min     -3.078490e+03
# 25%      1.380311e+04
# 50%      2.475306e+04
# 75%      5.022952e+04
# max      1.241704e+07
# Name: Renewal_PreviousAvgMonthRevenue, dtype: float64
#
# Value counts of attribute :
#
# 283083.33    2
# 17772.00     2
# 35689.67     2
# 8119.67      2
# 26512.00     2
#             ..
# 13675.00     1
# 19927.00     1
# 12108.90     1
# 9474.10      1
# 16924.91     1
# Name: Renewal_PreviousAvgMonthRevenue, Length: 2611, dtype: int64
#
# Unique number of attribute :
#
# [     nan 61101.27 45740.22 ... 18955.78 41592.67 16924.91]
#
# Missing values in attribute :
#
# 509
#
# Missing values in attribute_% :
#
# 16.277582347297727
# attribute_name : Renewal_PreviousAvgDailyBalance
# Description of attribute :
#
# count    2.618000e+03
# mean     1.081702e+04
# std      6.741022e+04
# min     -1.375330e+05
# 25%      1.496572e+03
# 50%      3.379140e+03
# 75%      7.664015e+03
# max      3.129067e+06
# Name: Renewal_PreviousAvgDailyBalance, dtype: float64
#
# Value counts of attribute :
#
# 0.00       6
# 1460.02    2
# 918.67     2
# 2795.67    2
# 3610.33    2
#           ..
# 1574.83    1
# 2590.86    1
# 552.67     1
# 2008.89    1
# 4347.10    1
# Name: Renewal_PreviousAvgDailyBalance, Length: 2599, dtype: int64
#
# Unique number of attribute :
#
# [    nan  -11.78 -254.78 ... 2299.61 4674.33 4347.1 ]
#
# Missing values in attribute :
#
# 509
#
# Missing values in attribute_% :
#
# 16.277582347297727
# attribute_name : Renewal_TwoWeekBounces
# Description of attribute :
#
# count    3127.000000
# mean        0.037736
# std         0.228732
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         4.000000
# Name: Renewal_TwoWeekBounces, dtype: float64
#
# Value counts of attribute :
#
# 0    3030
# 1      79
# 2      16
# 4       1
# 3       1
# Name: Renewal_TwoWeekBounces, dtype: int64
#
# Unique number of attribute :
#
# [0 2 1 4 3]
#
# Missing values in attribute :
#
# 0
#
# Missing values in attribute_% :
#
# 0.0
# attribute_name : NumberOfBankStatements
# Description of attribute :
#
# count    3127.000000
# mean        2.442597
# std         0.857291
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         6.000000
# Name: NumberOfBankStatements, dtype: float64
#
# Value counts of attribute :
#
# 3    1971
# 2     574
# 1     472
# 0      85
# 4      21
# 5       3
# 6       1
# Name: NumberOfBankStatements, dtype: int64
#
# Unique number of attribute :
#
# [3 2 1 6 5 4 0]
#
# Missing values in attribute :
#
# 0
#
# Missing values in attribute_% :
#
# 0.0
# attribute_name : BankStatement_MA_OverdraftDays
# Description of attribute :
#
# count    3044.000000
# mean        1.252874
# std         2.695271
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.333333
# max        31.333333
# Name: BankStatement_MA_OverdraftDays, dtype: float64
#
# Value counts of attribute :
#
# 0.000000     1898
# 1.000000      136
# 0.333333      106
# 0.666666       96
# 2.000000       85
#              ...
# 17.000000       1
# 21.666666       1
# 3.250000        1
# 9.500000        1
# 15.666666       1
# Name: BankStatement_MA_OverdraftDays, Length: 75, dtype: int64
#
# Unique number of attribute :
#
# [ 6.666666 10.666666  0.        1.        5.666666  1.5       5.
#   0.333333  3.666666  6.        2.        0.666666  0.5       4.
#  10.333333  4.333333  4.5       2.5       2.666666  1.333333  1.666666
#  17.        3.       11.333333  7.5       7.333333  2.333333  8.
#   6.333333  4.666666 19.        7.666666  5.333333  7.        8.666666
#   8.333333  8.5       3.333333  9.       14.       13.666666  9.5
#  11.        3.25     21.666666 12.       21.       14.333333 12.666666
#   3.5      13.        6.25      9.333333 10.       20.        9.666666
#   5.5       6.5       0.25     15.       31.333333 11.666666  2.25
#  14.666666 25.       12.333333 15.333333 14.5      16.       10.5
#   4.75     22.        2.75     18.       15.666666       nan]
#
# Missing values in attribute :
#
# 83
#
# Missing values in attribute_% :
#
# 2.654301247201791
# attribute_name : BankStatement_MA_NumReturnItems
# Description of attribute :
#
# count    3044.000000
# mean        1.075307
# std         3.454255
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.666666
# max        98.333333
# Name: BankStatement_MA_NumReturnItems, dtype: float64
#
# Value counts of attribute :
#
# 0.000000     2083
# 0.333333      144
# 1.000000      114
# 0.666666       88
# 2.000000       68
#              ...
# 0.600000        1
# 41.000000       1
# 21.000000       1
# 98.333333       1
# 37.000000       1
# Name: BankStatement_MA_NumReturnItems, Length: 84, dtype: int64
#
# Unique number of attribute :
#
# [ 5.666666  9.        2.666666  0.        2.        1.        0.333333
#   4.333333  3.        1.333333  3.666666  3.333333  0.666666  1.666666
#   4.        2.333333  2.5       0.5       0.8       7.        6.
#   5.        8.       12.       10.333333 16.666666 25.       15.
#   6.666666  7.333333  5.333333  1.5      12.333333 15.333333  4.666666
#  10.666666 11.       22.333333 11.666666 26.333333  5.5       6.333333
#   3.75     32.       23.333333 20.       10.       25.333333  6.5
#  17.        9.333333 20.666666 12.666666 14.       13.333333 11.333333
#   0.25      0.6       9.666666 41.       21.        4.5       3.5
#  98.333333 26.        8.5      13.        8.333333  2.25     11.5
#  12.5      30.        7.666666  7.5      14.333333 12.75      8.666666
#  16.       10.5      29.       23.       19.333333 21.5      37.
#        nan]
#
# Missing values in attribute :
#
# 83
#
# Missing values in attribute_% :
#
# 2.654301247201791
# attribute_name : Credit_Score__c
# Description of attribute :
#
# count    3109.000000
# mean      549.587649
# std       153.385928
# min         0.000000
# 25%       532.000000
# 50%       578.000000
# 75%       621.000000
# max       815.000000
# Name: Credit_Score__c, dtype: float64
#
# Value counts of attribute :
#
# 0.0      163
# 595.0     32
# 550.0     30
# 1.0       29
# 578.0     28
#         ...
# 702.0      1
# 440.0      1
# 722.0      1
# 802.0      1
# 783.0      1
# Name: Credit_Score__c, Length: 319, dtype: int64
#
# Unique number of attribute :
#
# [576. 608. 662. 465. 616. 615.   0. 549. 553. 513. 650. 483. 535. 658.
#  581. 607. 572. 585. 550. 641. 560. 568. 516. 578. 514. 533. 557. 548.
#  527. 586. 564. 600. 511. 504. 523. 597. 628. 577. 538. 591. 534. 556.
#  545. 649. 501. 522. 491. 440. 654. 475. 579. 675.  nan 575. 592. 459.
#  562. 571. 584.   1. 603. 544. 512. 583. 587. 521. 543. 530. 566. 646.
#  438. 517. 617. 546. 558. 528. 588. 470. 622. 536. 489. 590. 620. 531.
#  481. 619. 633. 593. 488. 580. 547. 703. 573. 570. 627. 569. 598. 596.
#  614. 599. 507. 626. 653. 611. 519. 473. 604. 559. 510. 682. 640. 567.
#  661. 594. 492. 537. 493. 668. 612. 660. 563. 498. 496. 632. 499. 520.
#  539. 555. 644. 541. 495. 524. 552. 602. 625. 540. 471. 605. 506. 609.
#  529. 606. 722. 561. 502. 645. 621. 629. 667. 480. 589. 595. 500. 652.
#  484. 651. 582. 565. 638. 542. 699. 525. 509. 704. 574. 748. 688. 656.
#  637. 554. 532. 623. 453. 472. 690. 505. 487. 647. 515. 613. 479. 503.
#  665. 518. 551. 630. 494. 618. 643. 657. 526. 601. 464. 634. 485. 664.
#  497. 436. 463. 508. 676. 486. 482. 624. 636. 469. 655. 659. 631. 610.
#  768. 672. 700. 671. 462. 439. 635. 490. 474. 648. 694. 683. 452. 800.
#  448. 673. 663. 639. 478. 666. 736. 689. 695. 687. 712. 477. 426. 678.
#  467. 713. 744. 739. 457. 686. 714. 642. 684. 781. 709. 419. 677. 727.
#  456. 746. 441. 693. 708. 698. 791. 476. 691. 466. 815. 716. 715. 701.
#  767. 454. 753. 717. 710. 692. 449. 458. 705. 674. 679. 669. 741. 723.
#  759. 455. 445. 796. 468. 685. 725. 702. 696. 719. 681. 706. 802. 756.
#  813. 730. 788. 718. 711. 451. 697. 743. 740. 749. 729. 680. 670. 778.
#  721. 754. 755. 734. 461. 758. 761. 707. 735. 742. 752. 783.]
#
# Missing values in attribute :
#
# 18
#
# Missing values in attribute_% :
#
# 0.5756315957787016
# attribute_name : Time_in_Business__c
# Description of attribute :
#
# count    3126.000000
# mean        7.580384
# std        10.130543
# min         0.010000
# 25%         1.920000
# 50%         4.050000
# 75%         9.350000
# max       115.290000
# Name: Time_in_Business__c, dtype: float64
#
# Value counts of attribute :
#
# 4.05     17
# 2.19     13
# 1.32     12
# 0.84     11
# 0.92     11
#          ..
# 6.47      1
# 23.16     1
# 9.68      1
# 7.35      1
# 21.54     1
# Name: Time_in_Business__c, Length: 1398, dtype: int64
#
# Unique number of attribute :
#
# [48.11 48.36 48.63 ... 19.23 13.03 21.54]
#
# Missing values in attribute :
#
# 1
#
# Missing values in attribute_% :
#
# 0.03197953309881676
# attribute_name : HB_with_LCF_Payment__c
# Description of attribute :
#
# count     3127.000000
# mean        34.034416
# std        216.312897
# min          0.000000
# 25%         11.235000
# 50%         20.520000
# 75%         35.115000
# max      11539.840000
# Name: HB_with_LCF_Payment__c, dtype: float64
#
# Value counts of attribute :
#
# 0.00      400
# 10.26       6
# 16.10       5
# 9.71        5
# 14.25       4
#          ...
# 37.08       1
# 20.76       1
# 70.56       1
# 62.78       1
# 127.71      1
# Name: HB_with_LCF_Payment__c, Length: 2152, dtype: int64
#
# Unique number of attribute :
#
# [  0.    23.01  32.02 ...  12.01  17.58 127.71]
#
# Missing values in attribute :
#
# 0
#
# Missing values in attribute_% :
#
# 0.0
# attribute_name : AvgMonthlydeposits
# Description of attribute :
#
# count    3.044000e+03
# mean     7.323513e+04
# std      3.005807e+05
# min     -3.078493e+03
# 25%      1.575295e+04
# 50%      2.804607e+04
# 75%      5.704507e+04
# max      1.241704e+07
# Name: AvgMonthlydeposits, dtype: float64
#
# Value counts of attribute :
#
# 2.651200e+04    2
# 1.366900e+04    2
# 6.110127e+04    1
# 3.298571e+04    1
# 4.489390e+04    1
#                ..
# 3.787413e+04    1
# 2.612742e+04    1
# 2.845393e+04    1
# 1.995800e+04    1
# 1.141400e+06    1
# Name: AvgMonthlydeposits, Length: 3042, dtype: int64
#
# Unique number of attribute :
#
# [  61101.27       45740.223333   52053.666666 ... 3162730.
#  1141399.663333            nan]
#
# Missing values in attribute :
#
# 83
#
# Missing values in attribute_% :
#
# 2.654301247201791
# attribute_name : AvgDailybalance
# Description of attribute :
#
# count    3.044000e+03
# mean     1.161529e+04
# std      6.828568e+04
# min     -1.365124e+05
# 25%      1.483606e+03
# 50%      3.339711e+03
# 75%      7.869307e+03
# max      3.129067e+06
# Name: AvgDailybalance, dtype: float64
#
# Value counts of attribute :
#
# 2036.000000      2
# 1361.000000      2
# 1140.333333      2
# 2916.666666      2
# 2354.280000      2
#                 ..
# 4511.033333      1
# 6336.163333      1
# 17.150000        1
# 3019.313333      1
# 287640.446666    1
# Name: AvgDailybalance, Length: 3034, dtype: int64
#
# Unique number of attribute :
#
# [-1.17766660e+01 -2.54776666e+02 -4.83666666e+02 ...  5.35297900e+04
#   2.87640447e+05             nan]
#
# Missing values in attribute :
#
# 83
#
# Missing values in attribute_% :
#
# 2.654301247201791
# attribute_name : FundedAmount
# Description of attribute :
#
# count       3127.000000
# mean       21708.439603
# std        48690.710598
# min         1709.000000
# 25%         6000.000000
# 50%        10000.000000
# 75%        20000.000000
# max      1000000.000000
# Name: FundedAmount, dtype: float64
#
# Value counts of attribute :
#
# 10000.00    345
# 5000.00     270
# 15000.00    227
# 6000.00     214
# 8000.00     194
#            ...
# 35989.92      1
# 8300.00       1
# 21500.00      1
# 28000.00      1
# 5100.00       1
# Name: FundedAmount, Length: 168, dtype: int64
#
# Unique number of attribute :
#
# [  16500.     17000.      1800.      2000.      1709.      5000.
#     3000.      5592.      3500.      2400.      2500.      4000.
#     3600.      3300.      5500.      2300.      3200.      4200.
#     6000.      4340.      4500.      6500.      7500.      7000.
#     4400.      6100.      8500.      4300.      5300.      8000.
#     6700.     19021.      5200.      4600.      4650.      5250.
#    10000.      9000.      7300.      5600.     12000.     13000.
#     9400.      7700.      6400.      7850.      7050.      9500.
#     7800.     15000.     11000.     11600.     18000.     14000.
#    16000.     21000.     10625.     20000.     11500.      8800.
#    10500.     24000.     13500.     17500.     12500.     21262.
#    30000.     15500.     10050.     14500.     25000.     19000.
#     8700.     22000.     26000.     42000.     23000.     15950.
#    16275.     22500.     40000.     15750.     14600.     18500.
#    33000.     35000.     15395.     18275.     55000.     21317.79
#    45000.     50000.     16850.     38000.     34000.     22346.93
#    24200.     60000.     27000.     28000.     21500.      8300.
#    35989.92   25745.     70000.    100000.     43000.     35500.
#    33300.     30500.     51000.     45800.     46000.     66000.
#    65000.     54000.     90000.     85000.    258157.     36000.
#    31000.     75000.     95000.     32000.     61000.     80000.
#    37000.     39000.     72000.    120000.    114000.    130000.
#   219000.    200000.    125000.    300000.    170000.     44000.
#    53640.     46190.    108750.    134900.    111750.     85200.
#    47680.     90890.    119200.    141550.     55130.    149000.
#   129600.    136800.    115200.    145000.     58110.    107280.
#   178800.    168000.    169860.    193700.    100100.    147000.
#   141000.    290175.    110250.    265000.    186250.    134100.
#   170000.    187200.    390000.     88800.    253300.    146000.
#   174000.    144000.    298750.    111200.     65560.    113836.
#   109515.    163900.     77480.    103600.    201150.    260750.
#   640000.    181250.    216000.    223500.    442000.    327800.
#   283100.    312900.    424650.    429000.    590000.    176400.
#   161700.    268200.    143000.    335250.    781000.    365750.
#   347500.    318860.    447000.    409750.    725000.    401500.
#  1400000.   1117500.    558750.    284000.    783000.    707750.
#   652500.    894000.    922891.1   372500.    224000.    770000.
#   142000.      7599.     10960.     29200.     36500.     88200.
#    66150.  ]
#
# Missing values in attribute :
#
# 0
#
# Missing values in attribute_% :
#
# 0.0
# attribute_name : WriteOff_YN
# Description of attribute :
#
# count    3127.000000
# mean        0.256476
# std         0.436757
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: WriteOff_YN, dtype: float64
#
# Value counts of attribute :
#
# 0    2325
# 1     802
# Name: WriteOff_YN, dtype: int64
#
# Unique number of attribute :
#
# [0 1]
#
# Missing values in attribute :
#
# 0
#
# Missing values in attribute_% :
#
# 0.0
# attribute_name : FundedWriteOffAmount_Gross
# Description of attribute :
#
# count       802.000000
# mean       8965.585524
# std       23159.445056
# min           0.000000
# 25%         820.750000
# 50%        3526.080000
# 75%        8282.250000
# max      317759.340000
# Name: FundedWriteOffAmount_Gross, dtype: float64
#
# Value counts of attribute :
#
# 0.00        151
# 2404.00       2
# 1232.00       1
# 121.50        1
# 13957.00      1
#            ...
# 4255.00       1
# 3696.25       1
# 1639.00       1
# 3674.00       1
# 3764.00       1
# Name: FundedWriteOffAmount_Gross, Length: 651, dtype: int64
#
# Unique number of attribute :
#
# [          nan 1.2320000e+03 2.2176800e+03 1.7281100e+03 0.0000000e+00
#  1.3900000e+03 1.5696000e+03 1.4160000e+03 2.1040000e+03 4.2748000e+02
#  6.0200000e+02 3.3600000e+02 1.9255000e+03 2.4040000e+03 1.5100000e+03
#  3.9885000e+03 8.1700000e+02 1.3503800e+03 1.0049900e+03 1.6586200e+03
#  9.1300000e+02 4.4000000e+02 3.1570000e+03 1.0222500e+03 1.3908000e+03
#  2.4636000e+03 1.0796600e+03 3.0753300e+03 2.9530200e+03 3.2240000e+03
#  4.6760000e+03 1.5020000e+03 2.4160000e+03 2.2980000e+03 8.3200000e+02
#  2.7730000e+03 1.4690000e+03 2.1210000e+03 1.4110000e+03 5.3700000e+02
#  4.4060000e+03 1.4107200e+03 3.4238800e+03 1.8632400e+03 2.5100500e+03
#  2.5176100e+03 5.7740000e+02 1.3113900e+03 3.7020100e+03 5.1675000e+02
#  1.5223800e+03 2.2623800e+03 2.0063800e+03 2.6558000e+03 3.2120600e+03
#  3.6087100e+03 9.6685000e+02 3.3750000e+03 1.6631600e+03 1.1080400e+03
#  2.4920000e+03 9.5000000e+01 8.6222000e+02 4.0418800e+03 2.6920000e+03
#  3.8284830e+04 6.2400000e+02 8.8000200e+03 3.9831950e+04 2.3809560e+04
#  4.3290000e+03 1.9636680e+04 6.4850000e+03 7.4300270e+04 1.5556000e+03
#  4.5254000e+02 2.0613000e+04 2.1827540e+04 1.0300000e+00 3.7456830e+04
#  1.2541390e+04 4.3459000e+02 3.5030000e+03 1.9616000e+04 2.9334810e+04
#  3.1774830e+04 1.2407900e+04 1.6921200e+04 2.7806810e+04 4.0760130e+04
#  1.3295010e+04 1.4536680e+04 1.7765000e+04 3.1059940e+04 1.7625000e+04
#  6.0309350e+04 1.1002500e+04 4.4320000e+04 2.2896000e+04 1.1007220e+04
#  1.0604020e+04 1.4923310e+04 2.2538100e+03 2.1656050e+04 1.6135890e+04
#  3.5310000e+04 7.0963320e+04 2.4025340e+04 1.0000000e+04 5.1600000e+03
#  1.1078950e+04 1.0921000e+04 3.1163220e+04 8.6077150e+04 2.8477720e+04
#  5.6050400e+03 5.5654750e+04 8.4028000e+04 1.4612500e+04 4.4566650e+04
#  1.5256000e+03 6.0484680e+04 4.1249500e+03 9.0071250e+04 2.9910000e+04
#  1.2293790e+04 8.0963100e+03 8.7138500e+03 1.4246090e+04 1.2400100e+05
#  2.9555010e+04 4.3384200e+03 5.8280040e+04 1.5550010e+04 1.4904000e+04
#  1.6555938e+05 1.0514670e+05 3.7420000e+04 8.7356000e+04 2.9655000e+04
#  3.7434600e+04 1.7559470e+05 3.0822000e+04 9.0027500e+04 1.0887500e+04
#  9.5615140e+04 4.0629970e+04 1.3127692e+05 1.9426236e+05 3.1775934e+05
#  2.2254730e+05 2.3805000e+05 5.8248400e+04 2.3096500e+03 2.5071200e+03
#  8.1600000e+02 2.3800000e+03 1.2054120e+04 1.0588000e+04 1.2783150e+04
#  4.0634300e+03 2.3040620e+04 3.0513000e+04 7.7822000e+02 5.8317200e+03
#  3.9680000e+03 3.7640000e+03]
#
# Missing values in attribute :
#
# 2325
#
# Missing values in attribute_% :
#
# 74.35241445474897
# attribute_name : WOGross_AdvanceBalance
# Description of attribute :
#
# count      3127.000000
# mean      10114.786393
# std       31252.869939
# min           0.000000
# 25%           0.000000
# 50%        3379.000000
# 75%        8836.685000
# max      700000.000000
# Name: WOGross_AdvanceBalance, dtype: float64
#
# Value counts of attribute :
#
# 0.00       996
# 2235.00      4
# 0.10         4
# 4321.00      4
# 2980.00      4
#           ...
# 4620.00      1
# 5069.00      1
# 1569.00      1
# 6412.25      1
# 302.50       1
# Name: WOGross_AdvanceBalance, Length: 2039, dtype: int64
#
# Unique number of attribute :
#
# [ 8455.8   5978.43     0.   ... 44257.5    198.81   302.5 ]
#
# Missing values in attribute :
#
# 0
#
# Missing values in attribute_% :
#
# 0.0
# attribute_name : NetWO
# Description of attribute :
#
# count       802.000000
# mean       7303.081646
# std       20472.274427
# min           0.000000
# 25%           0.000000
# 50%        1995.095000
# 75%        7052.280000
# max      317759.340000
# Name: NetWO, dtype: float64
#
# Value counts of attribute :
#
# 0.00       284
# 2404.00      2
# 1346.39      2
#  5.5527810e+04 3.9028000e+04 1.4612500e+04 4.4566650e+04 6.0484680e+04
#  3.3402890e+04 2.9910000e+04 1.2293790e+04 8.7138500e+03 3.7460900e+03
#  8.9001000e+04 2.9555010e+04 5.8280040e+04 1.5550010e+04 1.4904000e+04
#  1.6355938e+05 1.0514670e+05 3.7420000e+04 8.7426000e+04 2.8455000e+04
#  3.7434600e+04 1.7314637e+05 3.0822000e+04 9.0027500e+04 1.0887500e+04
#  9.5314140e+04 4.0629970e+04 2.2858730e+04 3.1775934e+05 1.3810703e+05
#  2.3805000e+05 5.8248400e+04 2.5071200e+03 2.3800000e+03 1.1749960e+04
#  9.1680000e+03 1.2783150e+04 9.1343000e+02 2.3040620e+04 3.0513000e+04
#  7.7822000e+02 4.6317200e+03 3.7640000e+03]
#
# Missing values in attribute :
#
# 2325
#
# Missing values in attribute_% :
#
# 74.35241445474897
# attribute_name : Avg_ReturnItemdays
# Description of attribute :
#
# count    3044.000000
# mean        0.944558
# std         2.259546
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.666666
# max        34.000000
# Name: Avg_ReturnItemdays, dtype: float64
#
# Value counts of attribute :
#
# 0.000000     1998
# 0.333333      170
# 1.000000      140
# 0.666666       96
# 2.000000       65
#              ...
# 2.750000        1
# 2.250000        1
# 0.400000        1
# 1.200000        1
# 26.666666       1
# Name: Avg_ReturnItemdays, Length: 65, dtype: int64
#
# Unique number of attribute :
#
# [ 2.333333  5.       12.        0.        0.666666  1.5       1.
#   0.333333  5.666666  3.666666  8.        7.        5.333333 10.
#   1.666666  4.       10.333333  4.333333  2.        0.5       1.333333
#   6.666666  1.2       2.666666  3.        9.666666  4.666666  3.333333
#   9.333333  6.        0.4       8.333333 14.666666 10.666666  7.333333
#   8.666666  6.333333  2.5       2.25      3.5       2.75     12.333333
#   9.        7.666666  8.5      34.       11.666666 13.       13.333333
#   0.25      5.8      15.        7.5       5.5      19.333333  0.75
#   5.25      4.5       6.5       1.25     11.       18.333333 16.333333
#  11.333333 26.666666       nan]
#
# Missing values in attribute :
#
# 83
#
# Missing values in attribute_% :
#
# 2.654301247201791
# attribute_name : LatestMonth_ReturnItemDays
# Description of attribute :
#
# count    2412.000000
# mean        1.303483
# std         2.969487
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max        34.000000
# Name: LatestMonth_ReturnItemDays, dtype: float64
#
# Value counts of attribute :
#
# 0.0     1656
# 1.0      209
# 2.0      143
# 3.0      112
# 5.0       52
# 4.0       51
# 7.0       34
# 6.0       32
# 8.0       25
# 9.0       22
# 10.0      17
# 11.0      14
# 12.0      13
# 14.0       8
# 16.0       6
# 13.0       5
# 17.0       3
# 15.0       3
# 34.0       2
# 20.0       2
# 18.0       1
# 24.0       1
# 22.0       1
# Name: LatestMonth_ReturnItemDays, dtype: int64
#
# Unique number of attribute :
#
# [ 4.  5. 18.  0. nan  1.  2.  3. 10. 12. 14.  6.  9.  8.  7. 11. 16. 13.
#  17. 34. 15. 24. 20. 22.]
#
# Missing values in attribute :
#
# 715
#
# Missing values in attribute_% :
#
# 22.86536616565398
# attribute_name : PctChangeInReveune
# Description of attribute :
#
# count    2558.000000
# mean       -4.894435
# std       186.823607
# min     -9273.441572
# 25%        -0.183162
# 50%         0.081235
# 75%         0.316290
# max         7.308505
# Name: PctChangeInReveune, dtype: float64
#
# Value counts of attribute :
#
#  0.000000    7
# -0.335832    1
# -0.002544    1
# -0.077473    1
#  0.795547    1
#             ..
#  0.683974    1
#  0.340605    1
# -0.344337    1
# -0.456980    1
#  0.791991    1
# Name: PctChangeInReveune, Length: 2552, dtype: int64
#
# Unique number of attribute :
#
# [        nan -0.33583245  0.12128732 ... -0.25165465  0.27541407
#   0.79199062]
#
# Missing values in attribute :
#
# 569
#
# Missing values in attribute_% :
#
# 18.196354333226736
# attribute_name : PctAvgDailybalance2AvgMonthlyDeposits
# Description of attribute :
#
# count    3043.000000
# mean        0.304741
# std         3.863882
# min        -0.272989
# 25%         0.060301
# 50%         0.114671
# 75%         0.211150
# max       205.822636
# Name: PctAvgDailybalance2AvgMonthlyDeposits, dtype: float64
#
# Value counts of attribute :
#
#  0.110013    2
# -0.000193    1
#  0.034888    1
#  0.093934    1
#  0.189469    1
#             ..
#  0.069804    1
#  0.137190    1
#  1.033012    1
#  0.123534    1
#  0.252007    1
# Name: PctAvgDailybalance2AvgMonthlyDeposits, Length: 3042, dtype: int64
#
# Unique number of attribute :
#
# [-1.92794683e-04 -5.57015248e-03 -9.29175599e-03 ...  4.81951416e-01
#   1.69251849e-02  2.52006777e-01]
#
# Missing values in attribute :
#
# 84
#
# Missing values in attribute_% :
#
# 2.6862807803006077

# %% [markdown]
# # Missing Values

# %%
data.isnull().sum().sort_values(ascending = False)/len(data)*100
# Out:
# NetWO                                    74.352414
# FundedWriteOffAmount_Gross               74.352414
# LatestMonth_ReturnItemDays               22.865366
# Renewal_PreviousPaidPercentageOfRTR      19.699392
# PctChangeInReveune                       18.196354
# Renewal_PreviousAvgMonthRevenue          16.277582
# Renewal_PreviousAvgDailyBalance          16.277582
# PctAvgDailybalance2AvgMonthlyDeposits     2.686281
# Avg_ReturnItemdays                        2.654301
# AvgDailybalance                           2.654301
# AvgMonthlydeposits                        2.654301
# BankStatement_MA_OverdraftDays            2.654301
# BankStatement_MA_NumReturnItems           2.654301
# Credit_Score__c                           0.575632
# Renewal_PreviousPace                      0.319795
# Time_in_Business__c                       0.031980
# WOGross_AdvanceBalance                    0.000000
# Paybackamount                             0.000000
# WriteOff_YN                               0.000000
# OpportunityID                             0.000000
# FundedAmount                              0.000000
# HB_with_LCF_Payment__c                    0.000000
# NumberOfBankStatements                    0.000000
# Renewal_TwoWeekBounces                    0.000000
# Renewal_PreviousHBwLCF                    0.000000
# Renewal_PreviousPosition                  0.000000
# Renewal_PreviousCountBounces              0.000000
# Renewal_CountPreviousDeals                0.000000
# Is_this_Business_home_based__c_Yes        0.000000
# dtype: float64

# %%
missing_attributes = ['LatestMonth_ReturnItemDays',
                      'Renewal_PreviousPaidPercentageOfRTR',
                      'PctChangeInReveune',
                      'Renewal_PreviousAvgDailyBalance',         
                      'Renewal_PreviousAvgMonthRevenue', 
                      'PctAvgDailybalance2AvgMonthlyDeposits',   
                      'BankStatement_MA_OverdraftDays',           
                      'AvgMonthlydeposits',        
                      'BankStatement_MA_NumReturnItems',          
                      'AvgDailybalance',                         
                      'Avg_ReturnItemdays',                       
                      'Credit_Score__c',                          
                      'Renewal_PreviousPace',                 
                      'Time_in_Business__c']    

for col in missing_attributes:
  print('\033[1m'+'attribute_name :', col+'\033[0m')
  attribute_info(data[col])
# Out:
# attribute_name : LatestMonth_ReturnItemDays
# Description of attribute :
#
# count    2412.000000
# mean        1.303483
# std         2.969487
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max        34.000000
# Name: LatestMonth_ReturnItemDays, dtype: float64
#
# Value counts of attribute :
#
# 0.0     1656
# 1.0      209
# 2.0      143
# 3.0      112
# 5.0       52
# 4.0       51
# 7.0       34
# 6.0       32
# 8.0       25
# 9.0       22
# 10.0      17
# 11.0      14
# 12.0      13
# 14.0       8
# 16.0       6
# 13.0       5
# 17.0       3
# 15.0       3
# 34.0       2
# 20.0       2
# 18.0       1
# 24.0       1
# 22.0       1
# Name: LatestMonth_ReturnItemDays, dtype: int64
#
# Unique number of attribute :
#
# [ 4.  5. 18.  0. nan  1.  2.  3. 10. 12. 14.  6.  9.  8.  7. 11. 16. 13.
#  17. 34. 15. 24. 20. 22.]
#
# Missing values in attribute :
#
# 715
#
# Missing values in attribute_% :
#
# 22.86536616565398
# attribute_name : Renewal_PreviousPaidPercentageOfRTR
# Description of attribute :
#
# count    2511.000000
# mean        0.676014
# std         0.214361
# min         0.000000
# 25%         0.540000
# 50%         0.620000
# 75%         0.780000
# max         2.150000
# Name: Renewal_PreviousPaidPercentageOfRTR, dtype: float64
#
# Value counts of attribute :
#
# 0.52    119
# 0.53    117
# 0.51    104
# 0.60     99
# 0.56     90
#        ...
# 0.19      1
# 1.51      1
# 1.57      1
# 1.42      1
# 1.52      1
# Name: Renewal_PreviousPaidPercentageOfRTR, Length: 145, dtype: int64
#
# Unique number of attribute :
#
# [0.8  0.66 0.77  nan 1.11 0.97 0.63 0.82 0.88 0.13 0.33 0.75 0.6  0.55
#  0.94 1.16 0.61 0.93 0.84 0.51 1.5  0.58 0.62 0.65 0.7  0.52 0.64 1.04
#  1.25 0.85 1.   0.76 0.57 0.53 0.74 0.54 0.99 0.71 0.56 0.69 0.9  1.72
#  0.72 1.03 0.73 0.67 0.4  0.44 0.47 0.5  1.41 1.18 0.78 0.83 1.1  1.32
#  0.95 0.46 1.02 1.15 1.01 1.28 0.48 1.69 0.68 0.92 1.3  0.23 0.49 0.27
#  0.87 1.48 1.77 0.98 0.59 1.08 0.96 1.65 1.13 1.14 0.91 0.86 0.81 0.42
#  1.17 1.2  0.08 1.22 1.37 0.29 0.36 0.89 1.4  0.34 0.43 1.33 0.17 0.39
#  0.31 1.07 0.79 1.24 0.28 0.14 1.38 0.19 1.51 1.57 1.45 2.15 0.32 1.93
#  0.41 1.42 0.25 1.09 0.26 1.31 0.3  0.21 0.05 0.18 0.24 0.1  0.45 1.05
#  1.06 0.16 0.37 1.27 0.11 0.22 1.29 0.35 1.12 1.71 0.   0.12 1.34 0.2
#  0.38 1.76 0.15 1.39 1.36 1.52]
#
# Missing values in attribute :
#
# 616
#
# Missing values in attribute_% :
#
# 19.69939238887112
# attribute_name : PctChangeInReveune
# Description of attribute :
#
# count    2558.000000
# mean       -4.894435
# std       186.823607
# min     -9273.441572
# 25%        -0.183162
# 50%         0.081235
# 75%         0.316290
# max         7.308505
# Name: PctChangeInReveune, dtype: float64
#
# Value counts of attribute :
#
#  0.000000    7
# -0.335832    1
# -0.002544    1
# -0.077473    1
#  0.795547    1
#             ..
#  0.683974    1
#  0.340605    1
# -0.344337    1
# -0.456980    1
#  0.791991    1
# Name: PctChangeInReveune, Length: 2552, dtype: int64
#
# Unique number of attribute :
#
# [        nan -0.33583245  0.12128732 ... -0.25165465  0.27541407
#   0.79199062]
#
# Missing values in attribute :
#
# 569
#
# Missing values in attribute_% :
#
# 18.196354333226736
# attribute_name : Renewal_PreviousAvgDailyBalance
# Description of attribute :
#
# count    2.618000e+03
# mean     1.081702e+04
# std      6.741022e+04
# min     -1.375330e+05
# 25%      1.496572e+03
# 50%      3.379140e+03
# 75%      7.664015e+03
# max      3.129067e+06
# Name: Renewal_PreviousAvgDailyBalance, dtype: float64
#
# Value counts of attribute :
#
# 0.00       6
# 1460.02    2
# 918.67     2
# 2795.67    2
# 3610.33    2
#           ..
# 1574.83    1
# 2590.86    1
# 552.67     1
# 2008.89    1
# 4347.10    1
# Name: Renewal_PreviousAvgDailyBalance, Length: 2599, dtype: int64
#
# Unique number of attribute :
#
# [    nan  -11.78 -254.78 ... 2299.61 4674.33 4347.1 ]
#
# Missing values in attribute :
#
# 509
#
# Missing values in attribute_% :
#
# 16.277582347297727
# attribute_name : Renewal_PreviousAvgMonthRevenue
# Description of attribute :
#
# count    2.618000e+03
# mean     6.541885e+04
# std      3.020899e+05
# min     -3.078490e+03
# 25%      1.380311e+04
# 50%      2.475306e+04
# 75%      5.022952e+04
# max      1.241704e+07
# Name: Renewal_PreviousAvgMonthRevenue, dtype: float64
#
# Value counts of attribute :
#
# 283083.33    2
# 17772.00     2
# 35689.67     2
# 8119.67      2
# 26512.00     2
#             ..
# 13675.00     1
# 19927.00     1
# 12108.90     1
# 9474.10      1
# 16924.91     1
# Name: Renewal_PreviousAvgMonthRevenue, Length: 2611, dtype: int64
#
# Unique number of attribute :
#
# [     nan 61101.27 45740.22 ... 18955.78 41592.67 16924.91]
#
# Missing values in attribute :
#
# 509
#
# Missing values in attribute_% :
#
# 16.277582347297727
# attribute_name : PctAvgDailybalance2AvgMonthlyDeposits
# Description of attribute :
#
# count    3043.000000
# mean        0.304741
# std         3.863882
# min        -0.272989
# 25%         0.060301
# 50%         0.114671
# 75%         0.211150
# max       205.822636
# Name: PctAvgDailybalance2AvgMonthlyDeposits, dtype: float64
#
# Value counts of attribute :
#
#  0.110013    2
# -0.000193    1
#  0.034888    1
#  0.093934    1
#  0.189469    1
#             ..
#  0.069804    1
#  0.137190    1
#  1.033012    1
#  0.123534    1
#  0.252007    1
# Name: PctAvgDailybalance2AvgMonthlyDeposits, Length: 3042, dtype: int64
#
# Unique number of attribute :
#
# [-1.92794683e-04 -5.57015248e-03 -9.29175599e-03 ...  4.81951416e-01
#   1.69251849e-02  2.52006777e-01]
#
# Missing values in attribute :
#
# 84
#
# Missing values in attribute_% :
#
# 2.6862807803006077
# attribute_name : BankStatement_MA_OverdraftDays
# Description of attribute :
#
# count    3044.000000
# mean        1.252874
# std         2.695271
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.333333
# max        31.333333
# Name: BankStatement_MA_OverdraftDays, dtype: float64
#
# Value counts of attribute :
#
# 0.000000     1898
# 1.000000      136
# 0.333333      106
# 0.666666       96
# 2.000000       85
#              ...
# 17.000000       1
# 21.666666       1
# 3.250000        1
# 9.500000        1
# 15.666666       1
# Name: BankStatement_MA_OverdraftDays, Length: 75, dtype: int64
#
# Unique number of attribute :
#
# [ 6.666666 10.666666  0.        1.        5.666666  1.5       5.
#   0.333333  3.666666  6.        2.        0.666666  0.5       4.
#  10.333333  4.333333  4.5       2.5       2.666666  1.333333  1.666666
#  17.        3.       11.333333  7.5       7.333333  2.333333  8.
#   6.333333  4.666666 19.        7.666666  5.333333  7.        8.666666
#   8.333333  8.5       3.333333  9.       14.       13.666666  9.5
#  11.        3.25     21.666666 12.       21.       14.333333 12.666666
#   3.5      13.        6.25      9.333333 10.       20.        9.666666
#   5.5       6.5       0.25     15.       31.333333 11.666666  2.25
#  14.666666 25.       12.333333 15.333333 14.5      16.       10.5
#   4.75     22.        2.75     18.       15.666666       nan]
#
# Missing values in attribute :
#
# 83
#
# Missing values in attribute_% :
#
# 2.654301247201791
# attribute_name : AvgMonthlydeposits
# Description of attribute :
#
# count    3.044000e+03
# mean     7.323513e+04
# std      3.005807e+05
# min     -3.078493e+03
# 25%      1.575295e+04
# 50%      2.804607e+04
# 75%      5.704507e+04
# max      1.241704e+07
# Name: AvgMonthlydeposits, dtype: float64
#
# Value counts of attribute :
#
# 2.651200e+04    2
# 1.366900e+04    2
# 6.110127e+04    1
# 3.298571e+04    1
# 4.489390e+04    1
#                ..
# 3.787413e+04    1
# 2.612742e+04    1
# 2.845393e+04    1
# 1.995800e+04    1
# 1.141400e+06    1
# Name: AvgMonthlydeposits, Length: 3042, dtype: int64
#
# Unique number of attribute :
#
# [  61101.27       45740.223333   52053.666666 ... 3162730.
#  1141399.663333            nan]
#
# Missing values in attribute :
#
# 83
#
# Missing values in attribute_% :
#
# 2.654301247201791
# attribute_name : BankStatement_MA_NumReturnItems
# Description of attribute :
#
# count    3044.000000
# mean        1.075307
# std         3.454255
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.666666
# max        98.333333
# Name: BankStatement_MA_NumReturnItems, dtype: float64
#
# Value counts of attribute :
#
# 0.000000     2083
# 0.333333      144
# 1.000000      114
# 0.666666       88
# 2.000000       68
#              ...
# 0.600000        1
# 41.000000       1
# 21.000000       1
# 98.333333       1
# 37.000000       1
# Name: BankStatement_MA_NumReturnItems, Length: 84, dtype: int64
#
# Unique number of attribute :
#
# [ 5.666666  9.        2.666666  0.        2.        1.        0.333333
#   4.333333  3.        1.333333  3.666666  3.333333  0.666666  1.666666
#   4.        2.333333  2.5       0.5       0.8       7.        6.
#   5.        8.       12.       10.333333 16.666666 25.       15.
#   6.666666  7.333333  5.333333  1.5      12.333333 15.333333  4.666666
#  10.666666 11.       22.333333 11.666666 26.333333  5.5       6.333333
#   3.75     32.       23.333333 20.       10.       25.333333  6.5
#  17.        9.333333 20.666666 12.666666 14.       13.333333 11.333333
#   0.25      0.6       9.666666 41.       21.        4.5       3.5
#  98.333333 26.        8.5      13.        8.333333  2.25     11.5
#  12.5      30.        7.666666  7.5      14.333333 12.75      8.666666
#  16.       10.5      29.       23.       19.333333 21.5      37.
#        nan]
#
# Missing values in attribute :
#
# 83
#
# Missing values in attribute_% :
#
# 2.654301247201791
# attribute_name : AvgDailybalance
# Description of attribute :
#
# count    3.044000e+03
# mean     1.161529e+04
# std      6.828568e+04
# min     -1.365124e+05
# 25%      1.483606e+03
# 50%      3.339711e+03
# 75%      7.869307e+03
# max      3.129067e+06
# Name: AvgDailybalance, dtype: float64
#
# Value counts of attribute :
#
# 2036.000000      2
# 1361.000000      2
# 1140.333333      2
# 2916.666666      2
# 2354.280000      2
#                 ..
# 4511.033333      1
# 6336.163333      1
# 17.150000        1
# 3019.313333      1
# 287640.446666    1
# Name: AvgDailybalance, Length: 3034, dtype: int64
#
# Unique number of attribute :
#
# [-1.17766660e+01 -2.54776666e+02 -4.83666666e+02 ...  5.35297900e+04
#   2.87640447e+05             nan]
#
# Missing values in attribute :
#
# 83
#
# Missing values in attribute_% :
#
# 2.654301247201791
# attribute_name : Avg_ReturnItemdays
# Description of attribute :
#
# count    3044.000000
# mean        0.944558
# std         2.259546
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.666666
# max        34.000000
# Name: Avg_ReturnItemdays, dtype: float64
#
# Value counts of attribute :
#
# 0.000000     1998
# 0.333333      170
# 1.000000      140
# 0.666666       96
# 2.000000       65
#              ...
# 2.750000        1
# 2.250000        1
# 0.400000        1
# 1.200000        1
# 26.666666       1
# Name: Avg_ReturnItemdays, Length: 65, dtype: int64
#
# Unique number of attribute :
#
# [ 2.333333  5.       12.        0.        0.666666  1.5       1.
#   0.333333  5.666666  3.666666  8.        7.        5.333333 10.
#   1.666666  4.       10.333333  4.333333  2.        0.5       1.333333
#   6.666666  1.2       2.666666  3.        9.666666  4.666666  3.333333
#   9.333333  6.        0.4       8.333333 14.666666 10.666666  7.333333
#   8.666666  6.333333  2.5       2.25      3.5       2.75     12.333333
#   9.        7.666666  8.5      34.       11.666666 13.       13.333333
#   0.25      5.8      15.        7.5       5.5      19.333333  0.75
#   5.25      4.5       6.5       1.25     11.       18.333333 16.333333
#  11.333333 26.666666       nan]
#
# Missing values in attribute :
#
# 83
#
# Missing values in attribute_% :
#
# 2.654301247201791
# attribute_name : Credit_Score__c
# Description of attribute :
#
# count    3109.000000
# mean      549.587649
#
# 1
#
# Missing values in attribute_% :
#
# 0.03197953309881676

# %%
data['LatestMonth_ReturnItemDays'].fillna(data['LatestMonth_ReturnItemDays'].median(), inplace = True)
data['Renewal_PreviousPaidPercentageOfRTR'].fillna(data['Renewal_PreviousPaidPercentageOfRTR'].median(), inplace = True)
data['PctChangeInReveune'].fillna(data['PctChangeInReveune'].median(), inplace = True)
data['Renewal_PreviousAvgDailyBalance'].fillna(data['Renewal_PreviousAvgDailyBalance'].median(), inplace = True)
data['Renewal_PreviousAvgMonthRevenue'].fillna(data['Renewal_PreviousAvgMonthRevenue'].median(), inplace = True)
data['PctAvgDailybalance2AvgMonthlyDeposits'].fillna(data['PctAvgDailybalance2AvgMonthlyDeposits'].median(), inplace = True)
data['BankStatement_MA_OverdraftDays'].fillna(data['BankStatement_MA_OverdraftDays'].median(), inplace = True)
data['AvgMonthlydeposits'].fillna(data['AvgMonthlydeposits'].median(), inplace = True)
data['BankStatement_MA_NumReturnItems'].fillna(data['BankStatement_MA_NumReturnItems'].median(), inplace = True)
data['AvgDailybalance'].fillna(data['AvgDailybalance'].median(), inplace = True)
data['Avg_ReturnItemdays'].fillna(data['Avg_ReturnItemdays'].median(), inplace = True)
data['Renewal_PreviousPace'].fillna(data['Renewal_PreviousPace'].median(),inplace = True)
data['Time_in_Business__c'].fillna(data['Time_in_Business__c'].median(),inplace = True)

# %%
credit_mean = data[(data['Credit_Score__c'] != 0) & (data['Credit_Score__c'] != 1)]['Credit_Score__c'].mean()
credit_mean
# Out:
# 585.7521426122729

# %%
data['Credit_Score__c'].fillna(credit_mean,inplace = True)

# %%
data['NetWO'].fillna(0,inplace = True)
data['FundedWriteOffAmount_Gross'].fillna(0,inplace = True)

# %%
data.isnull().sum().sort_values(ascending = False)/len(data)*100
# Out:
# OpportunityID                            0.0
# HB_with_LCF_Payment__c                   0.0
# PctAvgDailybalance2AvgMonthlyDeposits    0.0
# PctChangeInReveune                       0.0
# LatestMonth_ReturnItemDays               0.0
# Avg_ReturnItemdays                       0.0
# NetWO                                    0.0
# WOGross_AdvanceBalance                   0.0
# FundedWriteOffAmount_Gross               0.0
# WriteOff_YN                              0.0
# Paybackamount                            0.0
# FundedAmount                             0.0
# AvgDailybalance                          0.0
# AvgMonthlydeposits                       0.0
# Time_in_Business__c                      0.0
# Renewal_PreviousPace                     0.0
# Credit_Score__c                          0.0
# BankStatement_MA_NumReturnItems          0.0
# BankStatement_MA_OverdraftDays           0.0
# NumberOfBankStatements                   0.0
# Renewal_TwoWeekBounces                   0.0
# Renewal_PreviousAvgDailyBalance          0.0
# Renewal_PreviousAvgMonthRevenue          0.0
# Renewal_PreviousHBwLCF                   0.0
# Renewal_PreviousPosition                 0.0
# Renewal_PreviousCountBounces             0.0
# Renewal_CountPreviousDeals               0.0
# Renewal_PreviousPaidPercentageOfRTR      0.0
# Is_this_Business_home_based__c_Yes       0.0
# dtype: float64

# %%
data.to_excel('/content/drive/MyDrive/LCF_Internal/Renewable_Model/EDA Approach-1/XGBoost Implementation/xgboost_v7/V7_final_EDA.xlsx',index = False)
